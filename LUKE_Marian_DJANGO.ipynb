# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedSSoliman/Leveraging-Pretrained-Language-Models-for-Code-Generation/blob/master/LUKE_Marian_DJANGO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import torch
torch.cuda.empty_cache()

# %% [markdown]
# # **Install dependencies**

# %%
# %%capture
# !pip install tensorflow
# !pip install keras
# !pip install netron
# !pip install nltk

# !pip install git+https://github.com/huggingface/transformers
# !pip install datasets
# !pip install nlp
# !pip install rouge-score
#!pip install sacrebleu
# !pip install git-python
# !pip install sentencepiece
#!pip install torchdata
#!pip install transformers
# !pip install sacrebleu==1.5.1
# !pip install tree-sitter
# !pip install evaluate

# %% [markdown]
# # **Import Libraries**

# %%
import transformers
import datasets
from datasets import load_dataset, load_metric
import logging
from transformers import BertTokenizer, GPT2Tokenizer, GPT2TokenizerFast, EncoderDecoderModel, Trainer, TrainingArguments, BertTokenizerFast
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments
from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer

logging.basicConfig(level=logging.INFO)

import types
import argparse
import logging
from functools import partial
import json

import torch
from torch import optim
from torch.utils.data import DataLoader
from tqdm import tqdm
from transformers import (
    BertGenerationConfig,
    BertGenerationEncoder,
    BertTokenizer,
    EncoderDecoderModel,
    EncoderDecoderConfig,
    GPT2LMHeadModel,
    GPT2TokenizerFast,
    Trainer,
    TrainingArguments,
    get_cosine_schedule_with_warmup,
)

import sacrebleu
import random
import numpy as np
#from tensorboardX import SummaryWriter

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
# %cd /content/drive/MyDrive/models/CodeGeneration/New/DJANGO/LUKE-Marian
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/DJANGO/LUKE-Marian

# %% [markdown]
# # **Load Data**

# %%
from datasets import load_dataset

raw_dataset = load_dataset("AhmedSSoliman/DJANGO")
# Out:
# WARNING:datasets.builder:Using custom data configuration AhmedSSoliman--DJANGO-3a814141e88829f9
# Downloading and preparing dataset csv/AhmedSSoliman--DJANGO to /root/.cache/huggingface/datasets/AhmedSSoliman___csv/AhmedSSoliman--DJANGO-3a814141e88829f9/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/117k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/AhmedSSoliman___csv/AhmedSSoliman--DJANGO-3a814141e88829f9/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
train_dataset= raw_dataset["train"]
val_dataset = raw_dataset["validation"]
test_dataset = raw_dataset["test"]

# %%
raw_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'nl', 'code'],
#         num_rows: 16000
#     })
#     test: Dataset({
#         features: ['Unnamed: 0', 'nl', 'code'],
#         num_rows: 1805
#     })
#     validation: Dataset({
#         features: ['Unnamed: 0', 'nl', 'code'],
#         num_rows: 1000
#     })
# })

# %% [markdown]
# # **Tokenizer**

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("studio-ousia/luke-base", use_fast = True)
tokenizer
# Out:
# Downloading:   0%|          | 0.00/1.04k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/836 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/15.3M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/33.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# PreTrainedTokenizer(name_or_path='studio-ousia/luke-base', vocab_size=50265, model_max_len=512, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'bos_token': AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'eos_token': AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'unk_token': AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'sep_token': AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'pad_token': AddedToken("<pad>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'cls_token': AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'mask_token': AddedToken("<mask>", rstrip=False, lstrip=True, single_word=False, normalized=True), 'additional_special_tokens': [AddedToken("<ent>", rstrip=False, lstrip=False, single_word=False, normalized=True), AddedToken("<ent2>", rstrip=False, lstrip=False, single_word=False, normalized=True)]})

# %% [markdown]
# # **Model**

# %%
model = EncoderDecoderModel.from_encoder_decoder_pretrained("studio-ousia/luke-base", "Helsinki-NLP/opus-mt-en-nl")
model
# Out:
# Downloading:   0%|          | 0.00/1.10G [00:00<?, ?B/s]
# Some weights of the model checkpoint at studio-ousia/luke-base were not used when initializing LukeModel: ['lm_head.dense.weight', 'entity_predictions.transform.LayerNorm.weight', 'lm_head.bias', 'entity_predictions.transform.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'entity_predictions.transform.LayerNorm.bias', 'entity_predictions.transform.dense.weight', 'entity_predictions.bias']
# - This IS expected if you are initializing LukeModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LukeModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/316M [00:00<?, ?B/s]
# Some weights of the model checkpoint at Helsinki-NLP/opus-mt-en-nl were not used when initializing MarianForCausalLM: ['model.encoder.layers.1.final_layer_norm.bias', 'model.encoder.layers.1.fc2.weight', 'model.encoder.layers.5.final_layer_norm.weight', 'model.encoder.layers.2.fc2.bias', 'model.encoder.layers.2.final_layer_norm.bias', 'model.encoder.layers.3.self_attn_layer_norm.bias', 'model.encoder.layers.2.self_attn.v_proj.bias', 'model.encoder.layers.5.self_attn.v_proj.weight', 'model.encoder.layers.0.fc2.bias', 'model.encoder.layers.2.self_attn.out_proj.bias', 'model.encoder.layers.2.fc1.weight', 'model.encoder.layers.3.self_attn.q_proj.bias', 'model.encoder.layers.0.self_attn.q_proj.weight', 'model.encoder.layers.2.fc2.weight', 'model.encoder.layers.1.self_attn.v_proj.bias', 'model.encoder.layers.1.self_attn.q_proj.bias', 'model.encoder.layers.4.final_layer_norm.weight', 'model.encoder.layers.5.self_attn_layer_norm.weight', 'model.encoder.layers.4.fc1.bias', 'final_logits_bias', 'model.encoder.layers.1.fc1.weight', 'model.encoder.layers.4.self_attn.q_proj.bias', 'model.encoder.layers.5.self_attn_layer_norm.bias', 'model.encoder.layers.1.self_attn.k_proj.weight', 'model.encoder.layers.5.fc1.bias', 'model.encoder.layers.1.final_layer_norm.weight', 'model.encoder.layers.4.fc2.bias', 'model.encoder.layers.5.fc1.weight', 'model.encoder.layers.0.self_attn.out_proj.weight', 'model.encoder.layers.1.self_attn.v_proj.weight', 'model.encoder.layers.3.final_layer_norm.bias', 'model.encoder.layers.2.final_layer_norm.weight', 'model.encoder.layers.1.fc2.bias', 'model.encoder.layers.4.self_attn.k_proj.bias', 'model.encoder.layers.2.self_attn.q_proj.bias', 'model.encoder.layers.3.fc2.weight', 'model.shared.weight', 'model.encoder.layers.0.self_attn.out_proj.bias', 'model.encoder.layers.0.fc1.bias', 'model.encoder.layers.3.final_layer_norm.weight', 'model.encoder.layers.0.self_attn.q_proj.bias', 'model.encoder.layers.3.fc1.bias', 'model.encoder.layers.5.self_attn.out_proj.weight', 'model.encoder.layers.1.self_attn.out_proj.bias', 'model.encoder.layers.3.self_attn.v_proj.bias', 'model.encoder.layers.4.self_attn.out_proj.weight', 'model.encoder.layers.0.final_layer_norm.bias', 'model.encoder.layers.4.self_attn_layer_norm.bias', 'model.encoder.layers.2.self_attn.v_proj.weight', 'model.encoder.layers.2.self_attn.k_proj.bias', 'model.encoder.layers.3.self_attn.k_proj.weight', 'model.encoder.layers.4.final_layer_norm.bias', 'model.encoder.layers.0.self_attn.v_proj.bias', 'model.encoder.layers.0.self_attn_layer_norm.weight', 'model.encoder.layers.0.self_attn.v_proj.weight', 'model.encoder.layers.4.self_attn.q_proj.weight', 'model.encoder.layers.0.fc1.weight', 'model.encoder.layers.2.fc1.bias', 'model.encoder.layers.5.self_attn.q_proj.bias', 'model.encoder.layers.0.self_attn.k_proj.bias', 'model.encoder.layers.5.self_attn.k_proj.weight', 'model.encoder.layers.3.self_attn.q_proj.weight', 'model.encoder.layers.4.self_attn.k_proj.weight', 'model.encoder.embed_tokens.weight', 'model.encoder.layers.3.self_attn_layer_norm.weight', 'model.encoder.layers.5.self_attn.q_proj.weight', 'model.encoder.layers.5.fc2.bias', 'model.encoder.layers.1.self_attn_layer_norm.bias', 'model.encoder.layers.3.self_attn.out_proj.bias', 'model.encoder.layers.1.self_attn.q_proj.weight', 'model.encoder.layers.2.self_attn.out_proj.weight', 'model.encoder.layers.3.fc1.weight', 'model.encoder.layers.2.self_attn.k_proj.weight', 'model.encoder.layers.4.fc2.weight', 'model.encoder.layers.3.self_attn.v_proj.weight', 'model.encoder.embed_positions.weight', 'model.encoder.layers.4.self_attn.out_proj.bias', 'model.encoder.layers.1.self_attn.out_proj.weight', 'model.encoder.layers.3.self_attn.k_proj.bias', 'model.encoder.layers.5.self_attn.k_proj.bias', 'model.encoder.layers.3.self_attn.out_proj.weight', 'model.encoder.layers.4.self_attn.v_proj.bias', 'model.encoder.layers.0.self_attn_layer_norm.bias', 'model.encoder.layers.3.fc2.bias', 'model.encoder.layers.2.self_attn_layer_norm.weigh ...
# - This IS expected if you are initializing MarianForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing MarianForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of MarianForCausalLM were not initialized from the model checkpoint at Helsinki-NLP/opus-mt-en-nl and are newly initialized: ['lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# EncoderDecoderModel(
#   (encoder): LukeModel(
#     (embeddings): LukeEmbeddings(
#       (word_embeddings): Embedding(50267, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (entity_embeddings): LukeEntityEmbeddings(
#       (entity_embeddings): Embedding(500000, 256, padding_idx=0)
#       (entity_embedding_dense): Linear(in_features=256, out_features=768, bias=False)
#       (position_embeddings): Embedding(514, 768)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): LukeEncoder(
#       (layer): ModuleList(
#         (0): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): LukePooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (decoder): MarianForCausalLM(
#     (model): MarianDecoderWrapper(
#       (decoder): MarianDecoder(
#         (embed_tokens): Embedding(67028, 512, padding_idx=67027)
#         (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#         (layers): ModuleList(
#           (0): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (3): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (4): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (5): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (lm_head): Linear(in_features=512, out_features=67028, bias=False)
#   )
#   (enc_to_dec_proj): Linear(in_features=768, out_features=512, bias=True)
# )

# %%
model.config
# Out:
# EncoderDecoderConfig {
#   "_commit_hash": null,
#   "decoder": {
#     "_name_or_path": "Helsinki-NLP/opus-mt-en-nl",
#     "_num_labels": 3,
#     "activation_dropout": 0.0,
#     "activation_function": "swish",
#     "add_bias_logits": false,
#     "add_cross_attention": true,
#     "add_final_layer_norm": false,
#     "architectures": [
#       "MarianMTModel"
#     ],
#     "attention_dropout": 0.0,
#     "bad_words_ids": [
#       [
#         67027
#       ]
#     ],
#     "bos_token_id": 0,
#     "chunk_size_feed_forward": 0,
#     "classif_dropout": 0.0,
#     "classifier_dropout": 0.0,
#     "cross_attention_hidden_size": null,
#     "d_model": 512,
#     "decoder_attention_heads": 8,
#     "decoder_ffn_dim": 2048,
#     "decoder_layerdrop": 0.0,
#     "decoder_layers": 6,
#     "decoder_start_token_id": 67027,
#     "decoder_vocab_size": 67028,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "dropout": 0.1,
#     "early_stopping": false,
#     "encoder_attention_heads": 8,
#     "encoder_ffn_dim": 2048,
#     "encoder_layerdrop": 0.0,
#     "encoder_layers": 6,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": 0,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": 0,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1",
#       "2": "LABEL_2"
#     },
#     "init_std": 0.02,
#     "is_decoder": true,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1,
#       "LABEL_2": 2
#     },
#     "length_penalty": 1.0,
#     "max_length": 512,
#     "max_position_embeddings": 512,
#     "min_length": 0,
#     "model_type": "marian",
#     "no_repeat_ngram_size": 0,
#     "normalize_before": false,
#     "normalize_embedding": false,
#     "num_beam_groups": 1,
#     "num_beams": 4,
#     "num_hidden_layers": 6,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": 67027,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "scale_embedding": true,
#     "sep_token_id": null,
#     "share_encoder_decoder_embeddings": true,
#     "static_position_embeddings": true,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": null,
#     "torchscript": false,
#     "transformers_version": "4.23.0.dev0",
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "vocab_size": 67028
#   },
#   "encoder": {
#     "_name_or_path": "studio-ousia/luke-base",
#     "add_cross_attention": false,
#     "architectures": [
#       "LukeForMaskedLM"
#     ],
#     "attention_probs_dropout_prob": 0.1,
#     "bad_words_ids": null,
#     "bert_model_name": "roberta-base",
#     "bos_token_id": 0,
#     "chunk_size_feed_forward": 0,
#     "classifier_dropout": null,
#     "cross_attention_hidden_size": null,
#     "decoder_start_token_id": null,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "early_stopping": false,
#     "encoder_no_repeat_ngram_size": 0,
#     "entity_emb_size": 256,
#     "entity_vocab_size": 500000,
#     "eos_token_id": 2,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "gradient_checkpointing": false,
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 768,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "initializer_range": 0.02,
#     "intermediate_size": 3072,
#     "is_decoder": false,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "layer_norm_eps": 1e-05,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "max_position_embeddings": 514,
#     "min_length": 0,
#     "model_type": "luke",
#     "no_repeat_ngram_size": 0,
#     "num_attention_heads": 12,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_hidden_layers": 12,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_past": true,
#     "output_scores": false,
#     "pad_token_id": 1,
#     "position_embedding_type": "absolute",
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "sep_token_id": null,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": "float32",
#     "torchscript": false,
#     "transformers_version": "4.23.0.dev0",
#     "type_vocab_size": 1,
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "use_entity_aware_attention": true,
#     "vocab_size": 50267
#   },
#   "is_encoder_decoder": true,
#   "model_type": "encoder-decoder",
#   "transformers_version": null
# }

# %%
model.base_model.config.encoder.num_hidden_layers = 6

# %%
model.tie_weights = True

# %%
model.base_model.config.decoder_start_token_id = model.base_model.config.decoder.bos_token_id

# %%
model.base_model.config.bos_token_id = tokenizer.bos_token_id
model.base_model.config.eos_token_id = tokenizer.eos_token_id
model.base_model.config.pad_token_id = tokenizer.pad_token_id

# %%
model.config.max_length =512

# %%
model.save_pretrained("LUKE-Marian-base-model")

# %%
from transformers import AutoModelForSeq2SeqLM
#model = AutoModelForSeq2SeqLM.from_pretrained("./LUKE-Marian-base-model")
model=AutoModelForSeq2SeqLM.from_pretrained("./LUKE-marian-training")
model
# Out:
# EncoderDecoderModel(
#   (encoder): LukeModel(
#     (embeddings): LukeEmbeddings(
#       (word_embeddings): Embedding(50267, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (entity_embeddings): LukeEntityEmbeddings(
#       (entity_embeddings): Embedding(500000, 256, padding_idx=0)
#       (entity_embedding_dense): Linear(in_features=256, out_features=768, bias=False)
#       (position_embeddings): Embedding(514, 768)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): LukeEncoder(
#       (layer): ModuleList(
#         (0): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): LukePooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (decoder): MarianForCausalLM(
#     (model): MarianDecoderWrapper(
#       (decoder): MarianDecoder(
#         (embed_tokens): Embedding(67028, 512, padding_idx=67027)
#         (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#         (layers): ModuleList(
#           (0): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (3): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (4): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (5): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (lm_head): Linear(in_features=512, out_features=67028, bias=False)
#   )
#   (enc_to_dec_proj): Linear(in_features=768, out_features=512, bias=True)
# )

# %%
model.base_model.config.decoder_start_token_id
# Out:
# 0

# %%
model.base_model.config.pad_token_id
# Out:
# 1

# %%
tokenizer.pad_token_id
# Out:
# 1

# %%
model.config
# Out:
# EncoderDecoderConfig {
#   "_commit_hash": null,
#   "_name_or_path": "./LUKE-Marian-base-model",
#   "architectures": [
#     "EncoderDecoderModel"
#   ],
#   "bos_token_id": 0,
#   "decoder": {
#     "_name_or_path": "Helsinki-NLP/opus-mt-en-nl",
#     "_num_labels": 3,
#     "activation_dropout": 0.0,
#     "activation_function": "swish",
#     "add_bias_logits": false,
#     "add_cross_attention": true,
#     "add_final_layer_norm": false,
#     "architectures": [
#       "MarianMTModel"
#     ],
#     "attention_dropout": 0.0,
#     "bad_words_ids": [
#       [
#         67027
#       ]
#     ],
#     "bos_token_id": 0,
#     "chunk_size_feed_forward": 0,
#     "classif_dropout": 0.0,
#     "classifier_dropout": 0.0,
#     "cross_attention_hidden_size": null,
#     "d_model": 512,
#     "decoder_attention_heads": 8,
#     "decoder_ffn_dim": 2048,
#     "decoder_layerdrop": 0.0,
#     "decoder_layers": 6,
#     "decoder_start_token_id": 67027,
#     "decoder_vocab_size": 67028,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "dropout": 0.1,
#     "early_stopping": false,
#     "encoder_attention_heads": 8,
#     "encoder_ffn_dim": 2048,
#     "encoder_layerdrop": 0.0,
#     "encoder_layers": 6,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": 0,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": 0,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1",
#       "2": "LABEL_2"
#     },
#     "init_std": 0.02,
#     "is_decoder": true,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1,
#       "LABEL_2": 2
#     },
#     "length_penalty": 1.0,
#     "max_length": 512,
#     "max_position_embeddings": 512,
#     "min_length": 0,
#     "model_type": "marian",
#     "no_repeat_ngram_size": 0,
#     "normalize_before": false,
#     "normalize_embedding": false,
#     "num_beam_groups": 1,
#     "num_beams": 4,
#     "num_hidden_layers": 6,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": 67027,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "scale_embedding": true,
#     "sep_token_id": null,
#     "share_encoder_decoder_embeddings": true,
#     "static_position_embeddings": true,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": null,
#     "torchscript": false,
#     "transformers_version": "4.23.0.dev0",
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "vocab_size": 67028
#   },
#   "decoder_start_token_id": 0,
#   "encoder": {
#     "_name_or_path": "studio-ousia/luke-base",
#     "add_cross_attention": false,
#     "architectures": [
#       "LukeForMaskedLM"
#     ],
#     "attention_probs_dropout_prob": 0.1,
#     "bad_words_ids": null,
#     "bert_model_name": "roberta-base",
#     "bos_token_id": 0,
#     "chunk_size_feed_forward": 0,
#     "classifier_dropout": null,
#     "cross_attention_hidden_size": null,
#     "decoder_start_token_id": null,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "early_stopping": false,
#     "encoder_no_repeat_ngram_size": 0,
#     "entity_emb_size": 256,
#     "entity_vocab_size": 500000,
#     "eos_token_id": 2,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "gradient_checkpointing": false,
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 768,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "initializer_range": 0.02,
#     "intermediate_size": 3072,
#     "is_decoder": false,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "layer_norm_eps": 1e-05,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "max_position_embeddings": 514,
#     "min_length": 0,
#     "model_type": "luke",
#     "no_repeat_ngram_size": 0,
#     "num_attention_heads": 12,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_hidden_layers": 6,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_past": true,
#     "output_scores": false,
#     "pad_token_id": 1,
#     "position_embedding_type": "absolute",
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "sep_token_id": null,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": "float32",
#     "torchscript": false,
#     "transformers_version": "4.23.0.dev0",
#     "type_vocab_size": 1,
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "use_entity_aware_attention": true,
#     "vocab_size": 50267
#   },
#   "eos_token_id": 2,
#   "is_encoder_decoder": true,
#   "max_length": 512,
#   "model_type": "encoder-decoder",
#   "pad_token_id": 1,
#   "torch_dtype": "float32",
#   "transformers_version": null
# }

# %% [markdown]
# # **Evaluator**

# %%
# %cd Utils
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/DJANGO/LUKE-Marian/Utils

# %%
from google.colab import files
import evaluator
evaluator = evaluator.CodeGenerationEvaluator(tokenizer, device,smooth_bleu=True)
# Out:
# Downloading builder script:   0%|          | 0.00/2.85k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.48k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.16k [00:00<?, ?B/s]

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/DJANGO/LUKE-Marian

# %% [markdown]
# # **Prepare the data.**

# %%
encoder_length = 32
decoder_length = 32
batch_size = 1


# map data correctly
def map_to_encoder_decoder_inputs(batch):
    inputs = tokenizer(batch["nl"], padding="max_length", truncation=True, max_length=encoder_length)
    outputs = tokenizer(batch["code"], padding="max_length", truncation=True, max_length=decoder_length)
    batch["input_ids"] = inputs.input_ids
    batch["attention_mask"] = inputs.attention_mask
    batch["decoder_input_ids"] = outputs.input_ids
    batch["labels"] = outputs.input_ids.copy()
    batch["decoder_attention_mask"] = outputs.attention_mask

    """
    # complicated list comprehension here because pad_token_id alone is not good enough to know whether label should be excluded or not
    batch["labels"] = [
        [-100 if mask == 0 else token for mask, token in mask_and_tokens] for mask_and_tokens in [zip(masks, labels) for masks, labels in zip(batch["decoder_attention_mask"], batch["labels"])]
    ]
    """
    assert all([len(x) == encoder_length for x in inputs.input_ids])
    assert all([len(x) == decoder_length for x in outputs.input_ids])

    return batch

# %%
# make train dataset ready
train_data = train_dataset.map(
    map_to_encoder_decoder_inputs, batched=True, batch_size=1, remove_columns=['nl', 'code'],
)
train_data.set_format(
    type="torch", columns=["input_ids", "attention_mask", "decoder_input_ids", "decoder_attention_mask", "labels"],
)
# Out:
#   0%|          | 0/16000 [00:00<?, ?ba/s]

# %%
# same for validation dataset
val_data = val_dataset.map(
    map_to_encoder_decoder_inputs, batched=True, batch_size=1, remove_columns=['nl', 'code'],
)
val_data.set_format(
    type="torch", columns=["input_ids", "attention_mask", "decoder_input_ids", "decoder_attention_mask", "labels"],
)
# Out:
#   0%|          | 0/1000 [00:00<?, ?ba/s]

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer,
                                       max_length=512,padding=True, ####new
                                       model = model)

# %% [markdown]
# # **Training**

# %%
# set training arguments - these params are not really tuned, feel free to change
training_args = Seq2SeqTrainingArguments(
    output_dir="./LUKE-marian-training1",
    evaluation_strategy="epoch",
    save_strategy = "epoch",
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    predict_with_generate=True,
    num_train_epochs=10,
    do_train=True,
    do_eval=True,
    fp16=True,
    overwrite_output_dir=True,
    learning_rate = 1e-5,
    weight_decay=0.01,
    warmup_ratio = 0.05,
    seed = 1995,
    save_total_limit = 2,
    load_best_model_at_end = True,
    #push_to_hub=True,
)
#

# instantiate trainer
trainer = Seq2SeqTrainer(
    model=model,
    tokenizer=tokenizer,
    args=training_args,
    compute_metrics=evaluator,
    data_collator = data_collator,
    train_dataset=train_data,
    eval_dataset =val_data,

)
#    save_total_limit=3,
#
# Out:
# Using cuda_amp half precision backend

# %%
# LUKE-Marian-Training
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 16000
#   Num Epochs = 10
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 1
#   Gradient Accumulation steps = 1
#   Total optimization steps = 160000
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
#     <div>
#
#       <progress value='160000' max='160000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [160000/160000 5:46:48, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Sacrebleu</th>
#       <th>Bleu-unigram-precision</th>
#       <th>Bleu-bigram-precision</th>
#       <th>Bleu-trigram-precision</th>
#       <th>Rouge-2</th>
#       <th>Rouge-l</th>
#       <th>Sacre-unigram-precision</th>
#       <th>Sacre-bigram-precision</th>
#       <th>Sacre-trigram-precision</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.219700</td>
#       <td>1.068214</td>
#       <td>21.008280</td>
#       <td>20.474057</td>
#       <td>46.585838</td>
#       <td>27.801784</td>
#       <td>16.153147</td>
#       <td>20.724757</td>
#       <td>50.169273</td>
#       <td>46.021721</td>
#       <td>25.811566</td>
#       <td>15.556565</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.655400</td>
#       <td>0.645707</td>
#       <td>39.863537</td>
#       <td>41.556994</td>
#       <td>59.102630</td>
#       <td>45.401542</td>
#       <td>34.893837</td>
#       <td>49.334785</td>
#       <td>72.485514</td>
#       <td>59.183515</td>
#       <td>45.817875</td>
#       <td>36.829044</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.513700</td>
#       <td>0.478135</td>
#       <td>48.514106</td>
#       <td>51.389446</td>
#       <td>64.550857</td>
#       <td>53.378569</td>
#       <td>44.024504</td>
#       <td>61.584337</td>
#       <td>81.117685</td>
#       <td>65.939880</td>
#       <td>55.206972</td>
#       <td>47.165317</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.390500</td>
#       <td>0.404736</td>
#       <td>67.728882</td>
#       <td>69.397814</td>
#       <td>82.744681</td>
#       <td>72.273810</td>
#       <td>63.450135</td>
#       <td>67.213070</td>
#       <td>84.837950</td>
#       <td>82.772622</td>
#       <td>72.838185</td>
#       <td>65.351506</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.330200</td>
#       <td>0.368558</td>
#       <td>71.087928</td>
#       <td>72.638915</td>
#       <td>85.652550</td>
#       <td>76.235465</td>
#       <td>68.224299</td>
#       <td>70.440135</td>
#       <td>86.938718</td>
#       <td>86.347377</td>
#       <td>77.658870</td>
#       <td>71.103414</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.268800</td>
#       <td>0.351472</td>
#       <td>73.054627</td>
#       <td>74.447856</td>
#       <td>87.990762</td>
#       <td>79.389596</td>
#       <td>71.882469</td>
#       <td>71.663714</td>
#       <td>87.998363</td>
#       <td>88.769729</td>
#       <td>80.796938</td>
#       <td>74.683704</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.236600</td>
#       <td>0.326114</td>
#       <td>71.961050</td>
#       <td>74.166659</td>
#       <td>83.414281</td>
#       <td>75.244900</td>
#       <td>68.338314</td>
#       <td>73.066316</td>
#       <td>88.835355</td>
#       <td>84.131366</td>
#       <td>76.654392</td>
#       <td>70.956012</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.223500</td>
#       <td>0.318868</td>
#       <td>75.056789</td>
#       <td>76.431601</td>
#       <td>87.873235</td>
#       <td>79.642383</td>
#       <td>72.550363</td>
#       <td>73.694696</td>
#       <td>89.168248</td>
#       <td>88.285799</td>
#       <td>80.630680</td>
#       <td>74.880412</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.204400</td>
#       <td>0.313614</td>
#       <td>75.444348</td>
#       <td>76.876457</td>
#       <td>88.336582</td>
#       <td>80.216177</td>
#       <td>73.366419</td>
#       <td>73.968324</td>
#       <td>89.243469</td>
#       <td>88.799683</td>
#       <td>81.351084</td>
#       <td>75.792330</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.194100</td>
#       <td>0.310413</td>
#       <td>75.827772</td>
#       <td>77.221883</td>
#       <td>88.427782</td>
#       <td>80.568720</td>
#       <td>73.927438</td>
#       <td>74.462823</td>
#       <td>89.501346</td>
#       <td>88.761150</td>
#       <td>81.606161</td>
#       <td>76.239211</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training/checkpoint-16000
# Configuration saved in ./LUKE-marian-training/checkpoint-16000/config.json
# Model weights saved in ./LUKE-marian-training/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training/checkpoint-16000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training/checkpoint-16000/added_tokens.json
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training/checkpoint-32000
# Configuration saved in ./LUKE-marian-training/checkpoint-32000/config.json
# Model weights saved in ./LUKE-marian-training/checkpoint-32000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training/checkpoint-32000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training/checkpoint-32000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training/checkpoint-32000/added_tokens.json
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training/checkpoint-48000
# Configuration saved in ./LUKE-marian-training/checkpoint-48000/config.json
# Model weights saved in ./LUKE-marian-training/checkpoint-48000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training/checkpoint-48000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training/checkpoint-48000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training/checkpoint-48000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training/checkpoint-16000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training/checkpoint-64000
# Configuration saved in ./LUKE-marian-training/checkpoint-64000/config.json
# Model weights saved in ./LUKE-marian-training/checkpoint-64000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training/checkpoint-64000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training/checkpoint-64000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training/checkpoint-64000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training/checkpoint-32000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training/checkpoint-80000
# Configuration saved in ./LUKE-marian-training/checkpoint-80000/config.json
# Model weights saved in ./LUKE-marian-training/checkpoint-80000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training/checkpoint-80000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training/checkpoint-80000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training/checkpoint-80000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training/checkpoint-48000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training/checkpoint-96000
# Configuration saved in ./LUKE-marian-training/checkpoint-96000/config.json
# Model weights saved in ./LUKE-marian-training/checkpoint-96000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training/checkpoint-96000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training/checkpoint-96000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training/checkpoint-96000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training/checkpoint-64000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training/checkpoint-112000
# Configuration saved in ./LUKE-marian-training/checkpoint-112000/config.json
# Model weights saved in ./LUKE-marian-training/checkpoint-112000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training/checkpoint-112000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training/checkpoint-112000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training/checkpoint-112000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training/checkpoint-80000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training/checkpoint-128000
# Configuration saved in ./LUKE-marian-training/checkpoint-128000/config.json
# Model weights saved in ./LUKE-marian-training/checkpoint-128000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training/checkpoint-128000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training/checkpoint-128000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training/checkpoint-128000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training/checkpoint-96000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training/checkpoint-144000
# Configuration saved in ./LUKE-marian-training/checkpoint-144000/config.json
# Model weights saved in ./LUKE-marian-training/checkpoint-144000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training/checkpoint-144000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training/checkpoint-144000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training/checkpoint-144000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training/checkpoint-112000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training/checkpoint-160000
# Configuration saved in ./LUKE-marian-training/checkpoint-160000/config.json
# Model weights saved in ./LUKE-marian-training/checkpoint-160000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training/checkpoint-160000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training/checkpoint-160000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training/checkpoint-160000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training/checkpoint-128000] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./LUKE-marian-training/checkpoint-160000 (score: 0.31041309237480164).
# TrainOutput(global_step=160000, training_loss=0.5992857362270355, metrics={'train_runtime': 20811.6359, 'train_samples_per_second': 7.688, 'train_steps_per_second': 7.688, 'total_flos': 2444269977600000.0, 'train_loss': 0.5992857362270355, 'epoch': 10.0})

# %%
# LUKE-Marian-Training1
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 16000
#   Num Epochs = 10
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 1
#   Gradient Accumulation steps = 1
#   Total optimization steps = 160000
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
#     <div>
#
#       <progress value='160000' max='160000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [160000/160000 3:45:16, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Sacrebleu</th>
#       <th>Bleu-unigram-precision</th>
#       <th>Bleu-bigram-precision</th>
#       <th>Bleu-trigram-precision</th>
#       <th>Rouge-2</th>
#       <th>Rouge-l</th>
#       <th>Sacre-unigram-precision</th>
#       <th>Sacre-bigram-precision</th>
#       <th>Sacre-trigram-precision</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.251700</td>
#       <td>0.326749</td>
#       <td>69.640276</td>
#       <td>72.032831</td>
#       <td>81.266227</td>
#       <td>73.030841</td>
#       <td>65.994523</td>
#       <td>73.597522</td>
#       <td>88.897355</td>
#       <td>82.097234</td>
#       <td>74.516749</td>
#       <td>68.823728</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.179200</td>
#       <td>0.304085</td>
#       <td>76.300378</td>
#       <td>77.559323</td>
#       <td>89.017089</td>
#       <td>81.324050</td>
#       <td>74.802276</td>
#       <td>74.665659</td>
#       <td>89.409518</td>
#       <td>89.031042</td>
#       <td>81.999339</td>
#       <td>76.675305</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.163100</td>
#       <td>0.300092</td>
#       <td>77.783279</td>
#       <td>79.153632</td>
#       <td>88.670743</td>
#       <td>81.528662</td>
#       <td>75.456279</td>
#       <td>76.019949</td>
#       <td>90.168286</td>
#       <td>89.031688</td>
#       <td>82.530186</td>
#       <td>77.672267</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.132000</td>
#       <td>0.299050</td>
#       <td>77.998961</td>
#       <td>79.089137</td>
#       <td>89.431954</td>
#       <td>82.624589</td>
#       <td>76.656981</td>
#       <td>76.057694</td>
#       <td>90.334304</td>
#       <td>89.441975</td>
#       <td>83.002740</td>
#       <td>78.133824</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.126500</td>
#       <td>0.291409</td>
#       <td>78.728014</td>
#       <td>79.952460</td>
#       <td>90.014065</td>
#       <td>83.076550</td>
#       <td>77.092511</td>
#       <td>76.645574</td>
#       <td>90.687700</td>
#       <td>90.277915</td>
#       <td>83.942487</td>
#       <td>79.168716</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.096400</td>
#       <td>0.289145</td>
#       <td>79.376731</td>
#       <td>80.514664</td>
#       <td>90.146183</td>
#       <td>83.655131</td>
#       <td>78.001378</td>
#       <td>77.045960</td>
#       <td>90.956070</td>
#       <td>90.381574</td>
#       <td>84.401053</td>
#       <td>79.854966</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.084800</td>
#       <td>0.285971</td>
#       <td>80.125906</td>
#       <td>81.222499</td>
#       <td>90.951757</td>
#       <td>84.783141</td>
#       <td>79.601782</td>
#       <td>77.362381</td>
#       <td>91.135077</td>
#       <td>90.996721</td>
#       <td>85.369083</td>
#       <td>81.207472</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.092300</td>
#       <td>0.281029</td>
#       <td>79.655554</td>
#       <td>80.850255</td>
#       <td>89.495619</td>
#       <td>82.842785</td>
#       <td>77.192031</td>
#       <td>77.146958</td>
#       <td>91.066307</td>
#       <td>89.889616</td>
#       <td>83.750135</td>
#       <td>79.123274</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.087300</td>
#       <td>0.282877</td>
#       <td>80.636752</td>
#       <td>81.901749</td>
#       <td>91.026196</td>
#       <td>84.862831</td>
#       <td>79.322221</td>
#       <td>77.614806</td>
#       <td>91.405104</td>
#       <td>91.338272</td>
#       <td>85.698630</td>
#       <td>81.254603</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.075600</td>
#       <td>0.283955</td>
#       <td>80.536942</td>
#       <td>81.786718</td>
#       <td>89.872877</td>
#       <td>83.614400</td>
#       <td>78.149553</td>
#       <td>77.594641</td>
#       <td>91.369032</td>
#       <td>90.259614</td>
#       <td>84.555483</td>
#       <td>80.125801</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training1/checkpoint-16000
# Configuration saved in ./LUKE-marian-training1/checkpoint-16000/config.json
# Model weights saved in ./LUKE-marian-training1/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training1/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training1/checkpoint-16000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training1/checkpoint-16000/added_tokens.json
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training1/checkpoint-32000
# Configuration saved in ./LUKE-marian-training1/checkpoint-32000/config.json
# Model weights saved in ./LUKE-marian-training1/checkpoint-32000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training1/checkpoint-32000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training1/checkpoint-32000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training1/checkpoint-32000/added_tokens.json
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training1/checkpoint-48000
# Configuration saved in ./LUKE-marian-training1/checkpoint-48000/config.json
# Model weights saved in ./LUKE-marian-training1/checkpoint-48000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training1/checkpoint-48000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training1/checkpoint-48000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training1/checkpoint-48000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training1/checkpoint-16000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training1/checkpoint-64000
# Configuration saved in ./LUKE-marian-training1/checkpoint-64000/config.json
# Model weights saved in ./LUKE-marian-training1/checkpoint-64000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training1/checkpoint-64000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training1/checkpoint-64000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training1/checkpoint-64000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training1/checkpoint-32000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training1/checkpoint-80000
# Configuration saved in ./LUKE-marian-training1/checkpoint-80000/config.json
# Model weights saved in ./LUKE-marian-training1/checkpoint-80000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training1/checkpoint-80000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training1/checkpoint-80000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training1/checkpoint-80000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training1/checkpoint-48000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training1/checkpoint-96000
# Configuration saved in ./LUKE-marian-training1/checkpoint-96000/config.json
# Model weights saved in ./LUKE-marian-training1/checkpoint-96000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training1/checkpoint-96000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training1/checkpoint-96000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training1/checkpoint-96000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training1/checkpoint-64000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training1/checkpoint-112000
# Configuration saved in ./LUKE-marian-training1/checkpoint-112000/config.json
# Model weights saved in ./LUKE-marian-training1/checkpoint-112000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training1/checkpoint-112000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training1/checkpoint-112000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training1/checkpoint-112000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training1/checkpoint-80000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training1/checkpoint-128000
# Configuration saved in ./LUKE-marian-training1/checkpoint-128000/config.json
# Model weights saved in ./LUKE-marian-training1/checkpoint-128000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training1/checkpoint-128000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training1/checkpoint-128000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training1/checkpoint-128000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training1/checkpoint-96000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training1/checkpoint-144000
# Configuration saved in ./LUKE-marian-training1/checkpoint-144000/config.json
# Model weights saved in ./LUKE-marian-training1/checkpoint-144000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training1/checkpoint-144000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training1/checkpoint-144000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training1/checkpoint-144000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training1/checkpoint-112000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2319: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:533: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# The following columns in the evaluation set don't have a corresponding argument in `EncoderDecoderModel.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `EncoderDecoderModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 1
# Saving model checkpoint to ./LUKE-marian-training1/checkpoint-160000
# Configuration saved in ./LUKE-marian-training1/checkpoint-160000/config.json
# Model weights saved in ./LUKE-marian-training1/checkpoint-160000/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training1/checkpoint-160000/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training1/checkpoint-160000/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training1/checkpoint-160000/added_tokens.json
# Deleting older checkpoint [LUKE-marian-training1/checkpoint-144000] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./LUKE-marian-training1/checkpoint-128000 (score: 0.28102922439575195).
# TrainOutput(global_step=160000, training_loss=0.13358286004066466, metrics={'train_runtime': 13518.8093, 'train_samples_per_second': 11.835, 'train_steps_per_second': 11.835, 'total_flos': 2444269977600000.0, 'train_loss': 0.13358286004066466, 'epoch': 10.0})

# %%
trainer.save_model()
trainer.save_state()
# Out:
# Saving model checkpoint to ./LUKE-marian-training1
# Configuration saved in ./LUKE-marian-training1/config.json
# Model weights saved in ./LUKE-marian-training1/pytorch_model.bin
# tokenizer config file saved in ./LUKE-marian-training1/tokenizer_config.json
# Special tokens file saved in ./LUKE-marian-training1/special_tokens_map.json
# added tokens file saved in ./LUKE-marian-training1/added_tokens.json

# %% [markdown]
# # **Visualize**

# %%
# %load_ext tensorboard

# %% [markdown]
# ### **distilRoBERTa-marian**

# %%
tensorboard --logdir ./distilroberta-Marian-Training/runs

# %% [markdown]
# # **Inference**

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
new_model = AutoModelForSeq2SeqLM.from_pretrained("./LUKE-marian-training1/")
new_model.to("cuda")

new_tokenizer = AutoTokenizer.from_pretrained("./LUKE-marian-training1/", use_fast=True)

# %%
new_model
# Out:
# EncoderDecoderModel(
#   (encoder): LukeModel(
#     (embeddings): LukeEmbeddings(
#       (word_embeddings): Embedding(50267, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (entity_embeddings): LukeEntityEmbeddings(
#       (entity_embeddings): Embedding(500000, 256, padding_idx=0)
#       (entity_embedding_dense): Linear(in_features=256, out_features=768, bias=False)
#       (position_embeddings): Embedding(514, 768)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): LukeEncoder(
#       (layer): ModuleList(
#         (0): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): LukeLayer(
#           (attention): LukeAttention(
#             (self): LukeSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (w2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2w_query): Linear(in_features=768, out_features=768, bias=True)
#               (e2e_query): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LukeSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LukeIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LukeOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): LukePooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (decoder): MarianForCausalLM(
#     (model): MarianDecoderWrapper(
#       (decoder): MarianDecoder(
#         (embed_tokens): Embedding(67028, 512, padding_idx=67027)
#         (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#         (layers): ModuleList(
#           (0): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (3): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (4): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (5): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (lm_head): Linear(in_features=512, out_features=67028, bias=False)
#   )
#   (enc_to_dec_proj): Linear(in_features=768, out_features=512, bias=True)
# )

# %%
new_model.config.max_length
# Out:
# 512

# %% [markdown]
# # **Evaluator**

# %%
# %cd Utils
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/DJANGO/LUKE-Marian/Utils

# %%
from google.colab import files
import evaluator
evaluator = evaluator.CodeGenerationEvaluator(new_tokenizer, device,smooth_bleu=True)
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/DJANGO/LUKE-Marian/Utils/evaluator.py:32: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   self.sacre_bleu: Metric = load_metric('sacrebleu')
# Downloading builder script:   0%|          | 0.00/2.85k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.48k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.16k [00:00<?, ?B/s]

# %%
batch_size = 1

# map data correctly
def generate_new_code(batch):
    inputs = new_tokenizer(batch["nl"], padding="max_length", truncation=True, max_length=512, return_tensors="pt")

    input_ids = inputs.input_ids.to("cuda")
    attention_mask = inputs.attention_mask.to("cuda")

    outputs = new_model.generate(input_ids, attention_mask=attention_mask)

    # all special tokens including will be removed
    output_str = new_tokenizer.batch_decode(outputs, skip_special_tokens=True)

    batch["pred_code"] = output_str

    return batch

# %%
results = test_dataset.map(generate_new_code, batched=True, batch_size=batch_size)

#results = test_dataset.map(generate_new_code, batched=True, batch_size=batch_size, remove_columns=["intent"])
# Out:
#   0%|          | 0/1805 [00:00<?, ?ba/s]
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1261: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 512 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/DJANGO/LUKE-Marian

# %%
import re
import string

import datasets
import numpy as np

import evaluate
from evaluate import load

# %%
exact_match = evaluate.load("exact_match")

#refs = ["The cat sat on the mat.", "Theaters are great.", "It's like comparing oranges and apples."]
#preds = ["The cat sat on the mat?", "Theaters are great.", "It's like comparing apples and oranges."]

"""
for i in range(len(results)):
  refs = results["code"][i]
  preds = results["pred_code"][i]
"""
# Out:
# Downloading builder script:   0%|          | 0.00/5.67k [00:00<?, ?B/s]
# '\nfor i in range(len(results)):\n  refs = results["code"][i]\n  preds = results["pred_code"][i]\n'

# %%
refs = results["code"]
preds = results["pred_code"]

# %%
exact_match_results = exact_match.compute(references=refs, predictions=preds, regexes_to_ignore=["▁", " "], ignore_case=True, ignore_punctuation=True, ignore_numbers=True)
print(round(exact_match_results["exact_match"], 5)*100)
# Out:
# 78.50399999999999

# %%
with open("./references.txt", 'w') as f:
  for i in range(len(results)):
    nl = results["nl"][i]
    ref = results["code"][i]
    pred = results["pred_code"][i]

    if pred is not None and pred != "":
      if ref is not None and ref != "":
        f.write(ref + '\n')
    else:
      continue


with open("./predictions.txt", 'w') as f:
  for i in range(len(results)):
    nl = results["nl"][i]
    ref = results["code"][i]
    pred = results["pred_code"][i]

    if pred is not None and pred != "":
      if ref is not None and ref != "":
        f.write(pred + '\n')
    else:
      continue

# %%
# Ok Evaluator
bleu_score =0
rouge_score = 0
sacre_bleu = 0

for i in range(len(results)):
  ref = results["code"][i]
  pred = results["pred_code"][i]
  if pred is not None and pred != "":
      if ref is not None and ref != "":
        #bleu_metric = metric.compute(predictions=[pred], references=[[ref]])
        #bleu_score  += bleu_metric["score"]

        bleu_metric = evaluator.evaluate([pred], [ref])
        #bleu_metric = evaluator.evaluateSingle(pred, ref)

        #bleu_score += bleu_metric['BLEU-Unigram-Precision']
        bleu_score += bleu_metric['BLEU']
        rouge_score += bleu_metric['ROUGE-L']
        sacre_bleu += bleu_metric['SacreBLEU']
        #print(bleu_metric['SacreBLEU'])
  else:
    continue

# %% [markdown]
# # **Performance Metrics**

# %% [markdown]
# **BLEU Score**

# %%
# print("Bleu Score: ",bleu_score/len(results))
print('Bleu Score: {} (scale 0-100)'.format(bleu_score/len(results)))
# Out:
# Bleu Score: 89.34237231332078 (scale 0-100)

# %% [markdown]
# **SacreBLEU**

# %%
# print("Bleu Score: ",bleu_score/len(results))
print('Sacre Bleu: {} (scale 0-100)'.format(sacre_bleu/len(results)))
# Out:
# Sacre Bleu: 74.65832776226003 (scale 0-100)

# %% [markdown]
# **Rouge Score**

# %%
# print("Bleu Score: ",bleu_score/len(results))
print('ROUGE Score: {} (scale 0-100)'.format(rouge_score/len(results)))
# Out:
# ROUGE Score: 93.11333444068428 (scale 0-100)

# %% [markdown]
# **CodeBLEU**

# %%
from google.colab import files

# %%
import calc_code_bleu
ngram_match_score, weighted_ngram_match_score, syntax_match_score, dataflow_match_score, code_bleu_score = calc_code_bleu.calc_code_bleu("references.txt","predictions.txt","python", "keywords")

# %%
print("ngram_match_score: ", ngram_match_score*100)
print("weighted_ngram_match_score: ", weighted_ngram_match_score*100)
print("syntax_match_score: ", syntax_match_score*100)
print("dataflow_match_score: ", dataflow_match_score*100)
print("code_bleu_score: ", code_bleu_score*100)

# %% [markdown]
# # **Save the  results**

# %%
#%cd ..
# Out:
# /content/drive/MyDrive/models/CodeGeneration/MarianCG-CoNaLa-Large

# %%
bleu_score = 0
with open("./LUKE-marian-training1/Output.txt", 'w') as f:
  for i in range(len(results)):
    nl = results["nl"][i]
    ref = results["code"][i]
    pred = results["pred_code"][i]

    if pred is not None and pred != "":
      if ref is not None and ref != "":

        bleu_metric = evaluator.evaluate([pred], [ref])
        f.write( "NL: " + nl + '\n')
        f.write( "ref: " + ref + '\n')
        f.write( "Output: " + pred + '\n')
        f.write("bleu_metric: " + str(bleu_metric["BLEU"]) + '\n')
        f.write(10*"-" + '\n')
        bleu_score  += bleu_metric["BLEU"]

    else:
      continue

# %% [markdown]
# # **Test**

# %%
# map data correctly
def generate_code(NL):
    inputs = new_tokenizer([NL], padding="max_length", truncation=True, max_length=512, return_tensors="pt")

    input_ids = inputs.input_ids.to("cuda")
    attention_mask = inputs.attention_mask.to("cuda")

    outputs = new_model.generate(input_ids, attention_mask=attention_mask)

    # all special tokens including will be removed
    output_code = new_tokenizer.batch_decode(outputs, skip_special_tokens=True)

    return output_code

# %%
#NL = "decode a hex string to utf-8."
NL = "remove first and last lines of string `s`"
output_code = generate_code(NL)

# %%
output_code

# %%
natural_language = "How I can get rid of None values in dictionary?"
gen_code = generate_code(natural_language)

# %%
gen_code
