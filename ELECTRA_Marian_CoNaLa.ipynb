# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedSSoliman/Leveraging-Pretrained-Language-Models-for-Code-Generation/blob/master/ELECTRA_Marian_CoNaLa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import torch
torch.cuda.empty_cache()

# %% [markdown]
# # **Install dependencies**

# %%
# %%capture
# !pip install tensorflow
# !pip install keras
# !pip install netron
# !pip install nltk

# !pip install git+https://github.com/huggingface/transformers
# !pip install datasets
# !pip install nlp
# !pip install rouge-score
#!pip install sacrebleu
# !pip install git-python
# !pip install sentencepiece
#!pip install torchdata
#!pip install transformers
# !pip install sacrebleu==1.5.1
# !pip install tree-sitter
# !pip install evaluate

# %% [markdown]
# # **Import Libraries**

# %%
import transformers
import datasets
from datasets import load_dataset, load_metric
import logging
from transformers import BertTokenizer, GPT2Tokenizer, GPT2TokenizerFast, EncoderDecoderModel, Trainer, TrainingArguments, BertTokenizerFast
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments
from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer

logging.basicConfig(level=logging.INFO)

import types
import argparse
import logging
from functools import partial
import json

import torch
from torch import optim
from torch.utils.data import DataLoader
from tqdm import tqdm
from transformers import (
    BertGenerationConfig,
    BertGenerationEncoder,
    BertTokenizer,
    EncoderDecoderModel,
    EncoderDecoderConfig,
    GPT2LMHeadModel,
    GPT2TokenizerFast,
    Trainer,
    TrainingArguments,
    get_cosine_schedule_with_warmup,
)

import sacrebleu
import random
import numpy as np
#from tensorboardX import SummaryWriter

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
# %cd /content/drive/MyDrive/models/CodeGeneration/New/CoNaLa/ELECTRA-Marian
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/CoNaLa/ELECTRA-Marian

# %% [markdown]
# # **Load Data**

# %%
from datasets import load_dataset

raw_dataset = load_dataset("AhmedSSoliman/CoNaLa-Large")
# Out:
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_deprecation.py:97: FutureWarning: Deprecated argument(s) used in 'dataset_info': token. Will not be supported from version '0.12'.
#   warnings.warn(message, FutureWarning)
# WARNING:datasets.builder:Using custom data configuration AhmedSSoliman--CoNaLa-Large-87e6f6b36beed736
# Downloading and preparing dataset csv/AhmedSSoliman--CoNaLa-Large to /root/.cache/huggingface/datasets/AhmedSSoliman___csv/AhmedSSoliman--CoNaLa-Large-87e6f6b36beed736/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/2.32M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/51.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/117k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/AhmedSSoliman___csv/AhmedSSoliman--CoNaLa-Large-87e6f6b36beed736/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
train_dataset= raw_dataset["train"]
val_dataset = raw_dataset["validation"]
test_dataset = raw_dataset["test"]

# %%
raw_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['intent', 'snippet'],
#         num_rows: 24687
#     })
#     test: Dataset({
#         features: ['intent', 'snippet'],
#         num_rows: 500
#     })
#     validation: Dataset({
#         features: ['intent', 'snippet'],
#         num_rows: 1237
#     })
# })

# %% [markdown]
# # **Tokenizer**

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("google/electra-small-discriminator", use_fast = True)
tokenizer
# Out:
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# PreTrainedTokenizerFast(name_or_path='google/electra-small-discriminator', vocab_size=30522, model_max_len=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'})

# %% [markdown]
# # **Model**

# %%
model = EncoderDecoderModel.from_encoder_decoder_pretrained("google/electra-small-discriminator", "Helsinki-NLP/opus-mt-en-nl")
model
# Out:
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/54.2M [00:00<?, ?B/s]
# Some weights of the model checkpoint at google/electra-small-discriminator were not used when initializing ElectraModel: ['discriminator_predictions.dense.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense_prediction.bias']
# - This IS expected if you are initializing ElectraModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/316M [00:00<?, ?B/s]
# Some weights of the model checkpoint at Helsinki-NLP/opus-mt-en-nl were not used when initializing MarianForCausalLM: ['model.encoder.layers.5.fc2.bias', 'model.encoder.layers.0.self_attn.q_proj.bias', 'model.encoder.layers.2.fc2.bias', 'model.encoder.layers.0.self_attn_layer_norm.bias', 'model.encoder.layers.5.self_attn.v_proj.weight', 'model.shared.weight', 'model.encoder.layers.1.self_attn.v_proj.weight', 'model.encoder.layers.0.self_attn.k_proj.weight', 'model.encoder.layers.3.self_attn.q_proj.weight', 'model.encoder.layers.1.self_attn.q_proj.weight', 'model.encoder.layers.3.fc2.weight', 'model.encoder.layers.2.self_attn.q_proj.bias', 'model.encoder.layers.0.self_attn.v_proj.weight', 'model.encoder.layers.4.self_attn.k_proj.weight', 'model.encoder.layers.4.self_attn.v_proj.bias', 'model.encoder.layers.4.fc2.weight', 'model.encoder.layers.4.final_layer_norm.weight', 'model.encoder.layers.5.self_attn.out_proj.weight', 'model.encoder.layers.4.fc1.bias', 'model.encoder.layers.5.fc1.weight', 'model.encoder.layers.5.self_attn.k_proj.weight', 'model.encoder.layers.2.fc2.weight', 'model.encoder.layers.5.self_attn_layer_norm.weight', 'model.encoder.layers.5.fc2.weight', 'model.encoder.layers.0.fc2.weight', 'model.encoder.layers.4.self_attn.k_proj.bias', 'model.encoder.layers.1.final_layer_norm.bias', 'model.encoder.layers.0.fc1.weight', 'model.encoder.layers.3.self_attn.k_proj.weight', 'model.encoder.layers.3.self_attn.q_proj.bias', 'model.encoder.layers.2.self_attn_layer_norm.weight', 'model.encoder.embed_positions.weight', 'model.encoder.layers.3.self_attn.v_proj.weight', 'model.encoder.layers.3.self_attn.k_proj.bias', 'model.encoder.layers.0.self_attn_layer_norm.weight', 'model.encoder.layers.4.self_attn.v_proj.weight', 'model.encoder.layers.0.fc1.bias', 'model.encoder.layers.0.final_layer_norm.bias', 'model.encoder.layers.4.final_layer_norm.bias', 'model.encoder.layers.5.self_attn.k_proj.bias', 'model.encoder.layers.4.fc2.bias', 'model.encoder.layers.1.self_attn.k_proj.bias', 'model.encoder.layers.3.fc2.bias', 'model.encoder.layers.3.final_layer_norm.weight', 'model.encoder.layers.1.self_attn_layer_norm.weight', 'model.encoder.layers.4.self_attn_layer_norm.bias', 'model.encoder.layers.5.self_attn_layer_norm.bias', 'model.encoder.layers.2.final_layer_norm.bias', 'model.encoder.layers.0.self_attn.k_proj.bias', 'model.encoder.layers.1.self_attn.v_proj.bias', 'model.encoder.layers.5.fc1.bias', 'model.encoder.layers.2.fc1.weight', 'model.encoder.layers.0.self_attn.q_proj.weight', 'model.encoder.layers.0.fc2.bias', 'model.encoder.layers.3.final_layer_norm.bias', 'model.encoder.layers.0.final_layer_norm.weight', 'model.encoder.layers.1.fc1.weight', 'model.encoder.layers.2.self_attn.v_proj.weight', 'model.encoder.layers.0.self_attn.v_proj.bias', 'model.encoder.layers.1.self_attn.k_proj.weight', 'model.encoder.layers.3.self_attn.out_proj.bias', 'model.encoder.layers.5.final_layer_norm.weight', 'model.encoder.layers.1.self_attn.out_proj.bias', 'model.encoder.layers.5.self_attn.q_proj.bias', 'model.encoder.layers.2.self_attn.v_proj.bias', 'model.encoder.layers.4.self_attn.out_proj.bias', 'model.encoder.layers.1.fc1.bias', 'final_logits_bias', 'model.encoder.layers.1.fc2.bias', 'model.encoder.layers.2.self_attn.k_proj.weight', 'model.encoder.layers.3.self_attn_layer_norm.bias', 'model.encoder.layers.4.fc1.weight', 'model.encoder.layers.2.fc1.bias', 'model.encoder.layers.2.self_attn.out_proj.bias', 'model.encoder.layers.1.final_layer_norm.weight', 'model.encoder.layers.5.self_attn.out_proj.bias', 'model.encoder.layers.4.self_attn.q_proj.weight', 'model.encoder.layers.5.final_layer_norm.bias', 'model.encoder.layers.2.final_layer_norm.weight', 'model.encoder.layers.2.self_attn.out_proj.weight', 'model.encoder.layers.4.self_attn.out_proj.weight', 'model.encoder.layers.1.self_attn.out_proj.weight', 'model.encoder.layers.5.self_attn.v_proj.bias', 'model.encoder.layers.1.fc2.weight', 'model.encoder.layers.3.fc1.bias', 'model.encoder.layers.4.self ...
# - This IS expected if you are initializing MarianForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing MarianForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of MarianForCausalLM were not initialized from the model checkpoint at Helsinki-NLP/opus-mt-en-nl and are newly initialized: ['lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# EncoderDecoderModel(
#   (encoder): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(30522, 128, padding_idx=0)
#       (position_embeddings): Embedding(512, 128)
#       (token_type_embeddings): Embedding(2, 128)
#       (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (embeddings_project): Linear(in_features=128, out_features=256, bias=True)
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (decoder): MarianForCausalLM(
#     (model): MarianDecoderWrapper(
#       (decoder): MarianDecoder(
#         (embed_tokens): Embedding(67028, 512, padding_idx=67027)
#         (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#         (layers): ModuleList(
#           (0): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (3): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (4): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (5): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (lm_head): Linear(in_features=512, out_features=67028, bias=False)
#   )
#   (enc_to_dec_proj): Linear(in_features=256, out_features=512, bias=True)
# )

# %%
model.config
# Out:
# EncoderDecoderConfig {
#   "_commit_hash": null,
#   "decoder": {
#     "_name_or_path": "Helsinki-NLP/opus-mt-en-nl",
#     "_num_labels": 3,
#     "activation_dropout": 0.0,
#     "activation_function": "swish",
#     "add_bias_logits": false,
#     "add_cross_attention": true,
#     "add_final_layer_norm": false,
#     "architectures": [
#       "MarianMTModel"
#     ],
#     "attention_dropout": 0.0,
#     "bad_words_ids": [
#       [
#         67027
#       ]
#     ],
#     "bos_token_id": 0,
#     "chunk_size_feed_forward": 0,
#     "classif_dropout": 0.0,
#     "classifier_dropout": 0.0,
#     "cross_attention_hidden_size": null,
#     "d_model": 512,
#     "decoder_attention_heads": 8,
#     "decoder_ffn_dim": 2048,
#     "decoder_layerdrop": 0.0,
#     "decoder_layers": 6,
#     "decoder_start_token_id": 67027,
#     "decoder_vocab_size": 67028,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "dropout": 0.1,
#     "early_stopping": false,
#     "encoder_attention_heads": 8,
#     "encoder_ffn_dim": 2048,
#     "encoder_layerdrop": 0.0,
#     "encoder_layers": 6,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": 0,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": 0,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1",
#       "2": "LABEL_2"
#     },
#     "init_std": 0.02,
#     "is_decoder": true,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1,
#       "LABEL_2": 2
#     },
#     "length_penalty": 1.0,
#     "max_length": 512,
#     "max_position_embeddings": 512,
#     "min_length": 0,
#     "model_type": "marian",
#     "no_repeat_ngram_size": 0,
#     "normalize_before": false,
#     "normalize_embedding": false,
#     "num_beam_groups": 1,
#     "num_beams": 4,
#     "num_hidden_layers": 6,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": 67027,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "scale_embedding": true,
#     "sep_token_id": null,
#     "share_encoder_decoder_embeddings": true,
#     "static_position_embeddings": true,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": null,
#     "torchscript": false,
#     "transformers_version": "4.23.0.dev0",
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "vocab_size": 67028
#   },
#   "encoder": {
#     "_name_or_path": "google/electra-small-discriminator",
#     "add_cross_attention": false,
#     "architectures": [
#       "ElectraForPreTraining"
#     ],
#     "attention_probs_dropout_prob": 0.1,
#     "bad_words_ids": null,
#     "bos_token_id": null,
#     "chunk_size_feed_forward": 0,
#     "classifier_dropout": null,
#     "cross_attention_hidden_size": null,
#     "decoder_start_token_id": null,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "early_stopping": false,
#     "embedding_size": 128,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": null,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 256,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "initializer_range": 0.02,
#     "intermediate_size": 1024,
#     "is_decoder": false,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "layer_norm_eps": 1e-12,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "max_position_embeddings": 512,
#     "min_length": 0,
#     "model_type": "electra",
#     "no_repeat_ngram_size": 0,
#     "num_attention_heads": 4,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_hidden_layers": 12,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": 0,
#     "position_embedding_type": "absolute",
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "sep_token_id": null,
#     "summary_activation": "gelu",
#     "summary_last_dropout": 0.1,
#     "summary_type": "first",
#     "summary_use_proj": true,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": null,
#     "torchscript": false,
#     "transformers_version": "4.23.0.dev0",
#     "type_vocab_size": 2,
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "vocab_size": 30522
#   },
#   "is_encoder_decoder": true,
#   "model_type": "encoder-decoder",
#   "transformers_version": null
# }

# %%
model.base_model.config.encoder.num_hidden_layers = 6

# %%
model.tie_weights = True

# %%
model.base_model.config.decoder_start_token_id = model.base_model.config.decoder.bos_token_id

# %%
model.base_model.config.bos_token_id = tokenizer.bos_token_id
model.base_model.config.eos_token_id = tokenizer.eos_token_id
model.base_model.config.pad_token_id = tokenizer.pad_token_id

# %%
model.config.max_length =512

# %%
model.save_pretrained("ELECTRA-Marian-base-model")

# %%
from transformers import AutoModelForSeq2SeqLM
model = AutoModelForSeq2SeqLM.from_pretrained("./ELECTRA-Marian-base-model")
#model=AutoModelForSeq2SeqLM.from_pretrained("./ELECTRA-marian-training")
model
# Out:
# Some weights of the model checkpoint at ./ELECTRA-Marian-base-model were not used when initializing EncoderDecoderModel: ['encoder.encoder.layer.7.attention.self.value.weight', 'encoder.encoder.layer.10.intermediate.dense.bias', 'encoder.encoder.layer.6.intermediate.dense.weight', 'encoder.encoder.layer.11.attention.self.key.weight', 'encoder.encoder.layer.7.attention.output.LayerNorm.bias', 'encoder.encoder.layer.9.output.LayerNorm.bias', 'encoder.encoder.layer.10.attention.self.key.bias', 'encoder.encoder.layer.6.attention.output.dense.bias', 'encoder.encoder.layer.9.output.dense.weight', 'encoder.encoder.layer.10.attention.self.query.weight', 'encoder.encoder.layer.6.attention.self.key.bias', 'encoder.encoder.layer.11.attention.self.query.weight', 'encoder.encoder.layer.10.attention.output.dense.weight', 'encoder.encoder.layer.8.output.dense.weight', 'encoder.encoder.layer.9.attention.output.LayerNorm.bias', 'encoder.encoder.layer.6.output.LayerNorm.weight', 'encoder.encoder.layer.11.output.dense.bias', 'encoder.encoder.layer.10.attention.output.LayerNorm.bias', 'encoder.encoder.layer.11.attention.output.dense.weight', 'encoder.encoder.layer.6.attention.self.value.weight', 'encoder.encoder.layer.9.intermediate.dense.bias', 'encoder.encoder.layer.9.output.LayerNorm.weight', 'encoder.encoder.layer.6.attention.output.LayerNorm.bias', 'encoder.encoder.layer.10.attention.output.LayerNorm.weight', 'encoder.encoder.layer.11.attention.self.value.weight', 'encoder.encoder.layer.10.output.dense.weight', 'encoder.encoder.layer.10.attention.self.query.bias', 'encoder.encoder.layer.11.intermediate.dense.weight', 'encoder.encoder.layer.8.output.dense.bias', 'encoder.encoder.layer.7.attention.output.dense.bias', 'encoder.encoder.layer.8.attention.self.query.bias', 'encoder.encoder.layer.8.attention.output.dense.weight', 'encoder.encoder.layer.11.attention.self.value.bias', 'encoder.encoder.layer.6.attention.self.key.weight', 'encoder.encoder.layer.7.attention.self.query.bias', 'encoder.encoder.layer.10.output.LayerNorm.weight', 'encoder.encoder.layer.8.attention.output.dense.bias', 'encoder.encoder.layer.10.attention.self.key.weight', 'encoder.encoder.layer.8.output.LayerNorm.bias', 'encoder.encoder.layer.6.attention.self.value.bias', 'encoder.encoder.layer.7.attention.self.query.weight', 'encoder.encoder.layer.9.output.dense.bias', 'encoder.encoder.layer.7.output.dense.bias', 'encoder.encoder.layer.7.attention.output.LayerNorm.weight', 'encoder.encoder.layer.7.attention.self.key.weight', 'encoder.encoder.layer.9.attention.self.value.weight', 'encoder.encoder.layer.7.attention.self.value.bias', 'encoder.encoder.layer.9.attention.output.dense.weight', 'encoder.encoder.layer.11.attention.self.query.bias', 'encoder.encoder.layer.9.attention.self.query.weight', 'encoder.encoder.layer.10.output.LayerNorm.bias', 'encoder.encoder.layer.11.attention.output.LayerNorm.bias', 'encoder.encoder.layer.8.attention.output.LayerNorm.weight', 'encoder.encoder.layer.10.intermediate.dense.weight', 'encoder.encoder.layer.8.attention.self.query.weight', 'encoder.encoder.layer.8.intermediate.dense.weight', 'encoder.encoder.layer.6.attention.self.query.weight', 'encoder.encoder.layer.8.intermediate.dense.bias', 'encoder.encoder.layer.11.output.LayerNorm.weight', 'encoder.encoder.layer.11.intermediate.dense.bias', 'encoder.encoder.layer.9.attention.self.query.bias', 'encoder.encoder.layer.6.attention.output.LayerNorm.weight', 'encoder.encoder.layer.11.attention.output.dense.bias', 'encoder.encoder.layer.7.output.dense.weight', 'encoder.encoder.layer.6.intermediate.dense.bias', 'encoder.encoder.layer.7.attention.output.dense.weight', 'encoder.encoder.layer.7.output.LayerNorm.weight', 'encoder.encoder.layer.11.attention.output.LayerNorm.weight', 'encoder.encoder.layer.8.attention.self.key.bias', 'encoder.encoder.layer.9.attention.self.key.bias', 'encoder.encoder.layer.6.output.dense.weight', 'encoder.encoder.layer.8.attention.self.key.weight', 'encoder.encoder.laye ...
# - This IS expected if you are initializing EncoderDecoderModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing EncoderDecoderModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# EncoderDecoderModel(
#   (encoder): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (decoder): MarianForCausalLM(
#     (model): MarianDecoderWrapper(
#       (decoder): MarianDecoder(
#         (embed_tokens): Embedding(67028, 512, padding_idx=67027)
#         (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#         (layers): ModuleList(
#           (0): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (3): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (4): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (5): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (lm_head): Linear(in_features=512, out_features=67028, bias=False)
#   )
#   (enc_to_dec_proj): Linear(in_features=768, out_features=512, bias=True)
# )

# %%
model.base_model.config.decoder_start_token_id
# Out:
# 0

# %%
model.base_model.config.pad_token_id
# Out:
# 0

# %%
tokenizer.pad_token_id
# Out:
# 0

# %%
model.config
# Out:
# EncoderDecoderConfig {
#   "_commit_hash": null,
#   "_name_or_path": "./ELECTRA-Marian-base-model",
#   "architectures": [
#     "EncoderDecoderModel"
#   ],
#   "decoder": {
#     "_name_or_path": "Helsinki-NLP/opus-mt-en-nl",
#     "_num_labels": 3,
#     "activation_dropout": 0.0,
#     "activation_function": "swish",
#     "add_bias_logits": false,
#     "add_cross_attention": true,
#     "add_final_layer_norm": false,
#     "architectures": [
#       "MarianMTModel"
#     ],
#     "attention_dropout": 0.0,
#     "bad_words_ids": [
#       [
#         67027
#       ]
#     ],
#     "bos_token_id": 0,
#     "chunk_size_feed_forward": 0,
#     "classif_dropout": 0.0,
#     "classifier_dropout": 0.0,
#     "cross_attention_hidden_size": null,
#     "d_model": 512,
#     "decoder_attention_heads": 8,
#     "decoder_ffn_dim": 2048,
#     "decoder_layerdrop": 0.0,
#     "decoder_layers": 6,
#     "decoder_start_token_id": 67027,
#     "decoder_vocab_size": 67028,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "dropout": 0.1,
#     "early_stopping": false,
#     "encoder_attention_heads": 8,
#     "encoder_ffn_dim": 2048,
#     "encoder_layerdrop": 0.0,
#     "encoder_layers": 6,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": 0,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": 0,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1",
#       "2": "LABEL_2"
#     },
#     "init_std": 0.02,
#     "is_decoder": true,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1,
#       "LABEL_2": 2
#     },
#     "length_penalty": 1.0,
#     "max_length": 512,
#     "max_position_embeddings": 512,
#     "min_length": 0,
#     "model_type": "marian",
#     "no_repeat_ngram_size": 0,
#     "normalize_before": false,
#     "normalize_embedding": false,
#     "num_beam_groups": 1,
#     "num_beams": 4,
#     "num_hidden_layers": 6,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": 67027,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "scale_embedding": true,
#     "sep_token_id": null,
#     "share_encoder_decoder_embeddings": true,
#     "static_position_embeddings": true,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": null,
#     "torchscript": false,
#     "transformers_version": "4.23.0.dev0",
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "vocab_size": 67028
#   },
#   "decoder_start_token_id": 0,
#   "encoder": {
#     "_name_or_path": "google/electra-base-discriminator",
#     "add_cross_attention": false,
#     "architectures": [
#       "ElectraForPreTraining"
#     ],
#     "attention_probs_dropout_prob": 0.1,
#     "bad_words_ids": null,
#     "bos_token_id": null,
#     "chunk_size_feed_forward": 0,
#     "classifier_dropout": null,
#     "cross_attention_hidden_size": null,
#     "decoder_start_token_id": null,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "early_stopping": false,
#     "embedding_size": 768,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": null,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 768,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "initializer_range": 0.02,
#     "intermediate_size": 3072,
#     "is_decoder": false,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "layer_norm_eps": 1e-12,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "max_position_embeddings": 512,
#     "min_length": 0,
#     "model_type": "electra",
#     "no_repeat_ngram_size": 0,
#     "num_attention_heads": 12,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_hidden_layers": 6,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": 0,
#     "position_embedding_type": "absolute",
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "sep_token_id": null,
#     "summary_activation": "gelu",
#     "summary_last_dropout": 0.1,
#     "summary_type": "first",
#     "summary_use_proj": true,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": null,
#     "torchscript": false,
#     "transformers_version": "4.23.0.dev0",
#     "type_vocab_size": 2,
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "vocab_size": 30522
#   },
#   "is_encoder_decoder": true,
#   "max_length": 512,
#   "model_type": "encoder-decoder",
#   "pad_token_id": 0,
#   "torch_dtype": "float32",
#   "transformers_version": null
# }

# %% [markdown]
# # **Evaluator**

# %%
# %cd Utils
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/CoNaLa/ELECTRA-Marian/Utils

# %%
from google.colab import files
import evaluator
evaluator = evaluator.CodeGenerationEvaluator(tokenizer, device,smooth_bleu=True)
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/CoNaLa/ELECTRA-Marian/Utils/evaluator.py:32: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   self.sacre_bleu: Metric = load_metric('sacrebleu')
# Downloading builder script:   0%|          | 0.00/2.85k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.48k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.16k [00:00<?, ?B/s]

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/CoNaLa/ELECTRA-Marian

# %% [markdown]
# # **Prepare the data.**

# %%
encoder_length = 32
decoder_length = 32
batch_size = 1


# map data correctly
def map_to_encoder_decoder_inputs(batch):
    inputs = tokenizer(batch["intent"], padding="max_length", truncation=True, max_length=encoder_length)
    outputs = tokenizer(batch["snippet"], padding="max_length", truncation=True, max_length=decoder_length)
    batch["input_ids"] = inputs.input_ids
    batch["attention_mask"] = inputs.attention_mask
    batch["decoder_input_ids"] = outputs.input_ids
    batch["labels"] = outputs.input_ids.copy()
    batch["decoder_attention_mask"] = outputs.attention_mask

    """
    # complicated list comprehension here because pad_token_id alone is not good enough to know whether label should be excluded or not
    batch["labels"] = [
        [-100 if mask == 0 else token for mask, token in mask_and_tokens] for mask_and_tokens in [zip(masks, labels) for masks, labels in zip(batch["decoder_attention_mask"], batch["labels"])]
    ]
    """
    assert all([len(x) == encoder_length for x in inputs.input_ids])
    assert all([len(x) == decoder_length for x in outputs.input_ids])

    return batch

# %%
# make train dataset ready
train_data = train_dataset.map(
    map_to_encoder_decoder_inputs, batched=True, batch_size=8, remove_columns=['intent', 'snippet'],
)
train_data.set_format(
    type="torch", columns=["input_ids", "attention_mask", "decoder_input_ids", "decoder_attention_mask", "labels"],
)
# Out:
#   0%|          | 0/3086 [00:00<?, ?ba/s]

# %%
# same for validation dataset
val_data = val_dataset.map(
    map_to_encoder_decoder_inputs, batched=True, batch_size=4, remove_columns=['intent', 'snippet'],
)
val_data.set_format(
    type="torch", columns=["input_ids", "attention_mask", "decoder_input_ids", "decoder_attention_mask", "labels"],
)
# Out:
#   0%|          | 0/310 [00:00<?, ?ba/s]

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer,
                                       max_length=512,padding=True, ####new
                                       model = model)

# %% [markdown]
# # **Training**

# %%
# electra-marian-training
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 24687
#   Num Epochs = 10
#   Instantaneous batch size per device = 2
#   Total train batch size (w. parallel, distributed & accumulation) = 2
#   Gradient Accumulation steps = 1
#   Total optimization steps = 123440
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
#     <div>
#
#       <progress value='123440' max='123440' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [123440/123440 5:06:37, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Sacrebleu</th>
#       <th>Bleu-unigram-precision</th>
#       <th>Bleu-bigram-precision</th>
#       <th>Bleu-trigram-precision</th>
#       <th>Rouge-2</th>
#       <th>Rouge-l</th>
#       <th>Sacre-unigram-precision</th>
#       <th>Sacre-bigram-precision</th>
#       <th>Sacre-trigram-precision</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.693400</td>
#       <td>1.608480</td>
#       <td>5.773463</td>
#       <td>5.244755</td>
#       <td>20.574005</td>
#       <td>8.215015</td>
#       <td>3.549317</td>
#       <td>7.819445</td>
#       <td>17.889542</td>
#       <td>18.378220</td>
#       <td>7.212520</td>
#       <td>3.282697</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.293000</td>
#       <td>1.264493</td>
#       <td>16.438530</td>
#       <td>15.230776</td>
#       <td>46.070760</td>
#       <td>22.705930</td>
#       <td>11.864684</td>
#       <td>11.374251</td>
#       <td>24.371652</td>
#       <td>43.324756</td>
#       <td>19.897763</td>
#       <td>11.234961</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.125900</td>
#       <td>1.081485</td>
#       <td>19.513876</td>
#       <td>18.530506</td>
#       <td>46.245429</td>
#       <td>24.432489</td>
#       <td>13.932742</td>
#       <td>14.069141</td>
#       <td>27.810666</td>
#       <td>43.830615</td>
#       <td>22.230618</td>
#       <td>13.344077</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.979600</td>
#       <td>0.973508</td>
#       <td>23.402416</td>
#       <td>22.363382</td>
#       <td>49.190880</td>
#       <td>27.986938</td>
#       <td>17.623934</td>
#       <td>17.740810</td>
#       <td>31.836345</td>
#       <td>46.880743</td>
#       <td>25.785711</td>
#       <td>17.188530</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.833700</td>
#       <td>0.890920</td>
#       <td>26.495876</td>
#       <td>25.401274</td>
#       <td>52.877287</td>
#       <td>31.369704</td>
#       <td>20.669788</td>
#       <td>19.309055</td>
#       <td>34.702688</td>
#       <td>50.642398</td>
#       <td>29.195795</td>
#       <td>20.100697</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.750500</td>
#       <td>0.824155</td>
#       <td>29.339409</td>
#       <td>28.216673</td>
#       <td>55.754100</td>
#       <td>35.305372</td>
#       <td>24.634880</td>
#       <td>22.765795</td>
#       <td>37.850306</td>
#       <td>53.644803</td>
#       <td>33.264776</td>
#       <td>24.119729</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.698600</td>
#       <td>0.781699</td>
#       <td>32.494223</td>
#       <td>31.528766</td>
#       <td>58.188879</td>
#       <td>38.290486</td>
#       <td>27.816524</td>
#       <td>26.027131</td>
#       <td>40.897224</td>
#       <td>56.166810</td>
#       <td>36.410755</td>
#       <td>27.497830</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.609000</td>
#       <td>0.753871</td>
#       <td>34.759965</td>
#       <td>33.803172</td>
#       <td>58.976024</td>
#       <td>39.707763</td>
#       <td>29.514380</td>
#       <td>28.498630</td>
#       <td>42.911627</td>
#       <td>57.058736</td>
#       <td>37.929580</td>
#       <td>29.151396</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.623500</td>
#       <td>0.731300</td>
#       <td>35.498525</td>
#       <td>34.531137</td>
#       <td>59.448964</td>
#       <td>40.397156</td>
#       <td>30.149285</td>
#       <td>28.908415</td>
#       <td>43.570639</td>
#       <td>57.566941</td>
#       <td>38.562126</td>
#       <td>29.772536</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.588900</td>
#       <td>0.724949</td>
#       <td>36.085811</td>
#       <td>35.115960</td>
#       <td>60.277169</td>
#       <td>41.289492</td>
#       <td>31.038666</td>
#       <td>29.824849</td>
#       <td>44.228168</td>
#       <td>58.408887</td>
#       <td>39.486118</td>
#       <td>30.698864</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 5.77 and SacreBLEU of 5.24
# Saving model checkpoint to ./electra-marian-training/checkpoint-12344
# Configuration saved in ./electra-marian-training/checkpoint-12344/config.json
# Model weights saved in ./electra-marian-training/checkpoint-12344/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training/checkpoint-12344/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training/checkpoint-12344/special_tokens_map.json
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 16.44 and SacreBLEU of 15.23
# Saving model checkpoint to ./electra-marian-training/checkpoint-24688
# Configuration saved in ./electra-marian-training/checkpoint-24688/config.json
# Model weights saved in ./electra-marian-training/checkpoint-24688/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training/checkpoint-24688/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training/checkpoint-24688/special_tokens_map.json
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 19.51 and SacreBLEU of 18.53
# Saving model checkpoint to ./electra-marian-training/checkpoint-37032
# Configuration saved in ./electra-marian-training/checkpoint-37032/config.json
# Model weights saved in ./electra-marian-training/checkpoint-37032/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training/checkpoint-37032/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training/checkpoint-37032/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training/checkpoint-12344] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 23.40 and SacreBLEU of 22.36
# Saving model checkpoint to ./electra-marian-training/checkpoint-49376
# Configuration saved in ./electra-marian-training/checkpoint-49376/config.json
# Model weights saved in ./electra-marian-training/checkpoint-49376/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training/checkpoint-49376/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training/checkpoint-49376/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training/checkpoint-24688] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 26.50 and SacreBLEU of 25.40
# Saving model checkpoint to ./electra-marian-training/checkpoint-61720
# Configuration saved in ./electra-marian-training/checkpoint-61720/config.json
# Model weights saved in ./electra-marian-training/checkpoint-61720/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training/checkpoint-61720/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training/checkpoint-61720/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training/checkpoint-37032] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 29.34 and SacreBLEU of 28.22
# Saving model checkpoint to ./electra-marian-training/checkpoint-74064
# Configuration saved in ./electra-marian-training/checkpoint-74064/config.json
# Model weights saved in ./electra-marian-training/checkpoint-74064/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training/checkpoint-74064/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training/checkpoint-74064/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training/checkpoint-49376] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 32.49 and SacreBLEU of 31.53
# Saving model checkpoint to ./electra-marian-training/checkpoint-86408
# Configuration saved in ./electra-marian-training/checkpoint-86408/config.json
# Model weights saved in ./electra-marian-training/checkpoint-86408/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training/checkpoint-86408/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training/checkpoint-86408/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training/checkpoint-61720] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 34.76 and SacreBLEU of 33.80
# Saving model checkpoint to ./electra-marian-training/checkpoint-98752
# Configuration saved in ./electra-marian-training/checkpoint-98752/config.json
# Model weights saved in ./electra-marian-training/checkpoint-98752/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training/checkpoint-98752/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training/checkpoint-98752/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training/checkpoint-74064] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 35.50 and SacreBLEU of 34.53
# Saving model checkpoint to ./electra-marian-training/checkpoint-111096
# Configuration saved in ./electra-marian-training/checkpoint-111096/config.json
# Model weights saved in ./electra-marian-training/checkpoint-111096/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training/checkpoint-111096/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training/checkpoint-111096/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training/checkpoint-86408] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 36.09 and SacreBLEU of 35.12
# Saving model checkpoint to ./electra-marian-training/checkpoint-123440
# Configuration saved in ./electra-marian-training/checkpoint-123440/config.json
# Model weights saved in ./electra-marian-training/checkpoint-123440/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training/checkpoint-123440/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training/checkpoint-123440/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training/checkpoint-98752] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./electra-marian-training/checkpoint-123440 (score: 0.7249488234519958).
# TrainOutput(global_step=123440, training_loss=1.0755122609364083, metrics={'train_runtime': 18397.4208, 'train_samples_per_second': 13.419, 'train_steps_per_second': 6.71, 'total_flos': 3230087590379520.0, 'train_loss': 1.0755122609364083, 'epoch': 10.0})

# %%
# electra-marian-training-1
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 24687
#   Num Epochs = 10
#   Instantaneous batch size per device = 2
#   Total train batch size (w. parallel, distributed & accumulation) = 2
#   Gradient Accumulation steps = 1
#   Total optimization steps = 123440
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2280: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
#     <div>
#
#       <progress value='123440' max='123440' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [123440/123440 4:45:19, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Sacrebleu</th>
#       <th>Bleu-unigram-precision</th>
#       <th>Bleu-bigram-precision</th>
#       <th>Bleu-trigram-precision</th>
#       <th>Rouge-2</th>
#       <th>Rouge-l</th>
#       <th>Sacre-unigram-precision</th>
#       <th>Sacre-bigram-precision</th>
#       <th>Sacre-trigram-precision</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.588900</td>
#       <td>0.731743</td>
#       <td>35.477959</td>
#       <td>34.557771</td>
#       <td>60.173709</td>
#       <td>41.030753</td>
#       <td>30.680973</td>
#       <td>29.949791</td>
#       <td>44.498956</td>
#       <td>58.279140</td>
#       <td>39.156402</td>
#       <td>30.258050</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.490200</td>
#       <td>0.675500</td>
#       <td>38.981616</td>
#       <td>38.028823</td>
#       <td>64.731424</td>
#       <td>46.194185</td>
#       <td>35.981801</td>
#       <td>33.701098</td>
#       <td>47.501269</td>
#       <td>62.995043</td>
#       <td>44.444444</td>
#       <td>35.695884</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.471700</td>
#       <td>0.623139</td>
#       <td>43.301083</td>
#       <td>42.463347</td>
#       <td>65.020576</td>
#       <td>47.685140</td>
#       <td>38.396074</td>
#       <td>36.696980</td>
#       <td>49.760166</td>
#       <td>63.413552</td>
#       <td>46.137283</td>
#       <td>38.109414</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.408400</td>
#       <td>0.589857</td>
#       <td>45.220345</td>
#       <td>44.377554</td>
#       <td>66.998725</td>
#       <td>50.421179</td>
#       <td>41.497835</td>
#       <td>39.283359</td>
#       <td>52.306282</td>
#       <td>65.487306</td>
#       <td>48.993325</td>
#       <td>41.380702</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.344300</td>
#       <td>0.555869</td>
#       <td>48.640669</td>
#       <td>47.857617</td>
#       <td>69.237970</td>
#       <td>53.455557</td>
#       <td>44.806776</td>
#       <td>42.874560</td>
#       <td>55.002328</td>
#       <td>67.831819</td>
#       <td>52.110277</td>
#       <td>44.627393</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.308200</td>
#       <td>0.534941</td>
#       <td>50.819754</td>
#       <td>50.061328</td>
#       <td>70.785781</td>
#       <td>55.676910</td>
#       <td>47.217814</td>
#       <td>44.813585</td>
#       <td>56.741126</td>
#       <td>69.490086</td>
#       <td>54.428830</td>
#       <td>47.073907</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.298300</td>
#       <td>0.515950</td>
#       <td>53.144870</td>
#       <td>52.482729</td>
#       <td>70.907510</td>
#       <td>56.510139</td>
#       <td>48.619497</td>
#       <td>46.868024</td>
#       <td>58.338591</td>
#       <td>69.600819</td>
#       <td>55.290456</td>
#       <td>48.478634</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.256100</td>
#       <td>0.504350</td>
#       <td>53.690534</td>
#       <td>52.997381</td>
#       <td>71.441016</td>
#       <td>57.140080</td>
#       <td>49.268242</td>
#       <td>47.736105</td>
#       <td>59.316284</td>
#       <td>70.193012</td>
#       <td>55.908051</td>
#       <td>49.157912</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.272200</td>
#       <td>0.492279</td>
#       <td>54.974842</td>
#       <td>54.341020</td>
#       <td>71.871003</td>
#       <td>58.150569</td>
#       <td>50.545885</td>
#       <td>48.881139</td>
#       <td>60.319447</td>
#       <td>70.621991</td>
#       <td>56.975060</td>
#       <td>50.433965</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.257300</td>
#       <td>0.487997</td>
#       <td>54.891918</td>
#       <td>54.253749</td>
#       <td>72.558612</td>
#       <td>58.651069</td>
#       <td>51.031572</td>
#       <td>48.898963</td>
#       <td>60.114905</td>
#       <td>71.313370</td>
#       <td>57.481675</td>
#       <td>50.965683</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 35.48 and SacreBLEU of 34.56
# Saving model checkpoint to ./electra-marian-training-1/checkpoint-12344
# Configuration saved in ./electra-marian-training-1/checkpoint-12344/config.json
# Model weights saved in ./electra-marian-training-1/checkpoint-12344/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training-1/checkpoint-12344/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training-1/checkpoint-12344/special_tokens_map.json
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2280: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 38.98 and SacreBLEU of 38.03
# Saving model checkpoint to ./electra-marian-training-1/checkpoint-24688
# Configuration saved in ./electra-marian-training-1/checkpoint-24688/config.json
# Model weights saved in ./electra-marian-training-1/checkpoint-24688/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training-1/checkpoint-24688/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training-1/checkpoint-24688/special_tokens_map.json
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2280: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 43.30 and SacreBLEU of 42.46
# Saving model checkpoint to ./electra-marian-training-1/checkpoint-37032
# Configuration saved in ./electra-marian-training-1/checkpoint-37032/config.json
# Model weights saved in ./electra-marian-training-1/checkpoint-37032/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training-1/checkpoint-37032/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training-1/checkpoint-37032/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training-1/checkpoint-12344] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2280: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 45.22 and SacreBLEU of 44.38
# Saving model checkpoint to ./electra-marian-training-1/checkpoint-49376
# Configuration saved in ./electra-marian-training-1/checkpoint-49376/config.json
# Model weights saved in ./electra-marian-training-1/checkpoint-49376/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training-1/checkpoint-49376/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training-1/checkpoint-49376/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training-1/checkpoint-24688] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2280: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 48.64 and SacreBLEU of 47.86
# Saving model checkpoint to ./electra-marian-training-1/checkpoint-61720
# Configuration saved in ./electra-marian-training-1/checkpoint-61720/config.json
# Model weights saved in ./electra-marian-training-1/checkpoint-61720/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training-1/checkpoint-61720/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training-1/checkpoint-61720/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training-1/checkpoint-37032] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2280: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 50.82 and SacreBLEU of 50.06
# Saving model checkpoint to ./electra-marian-training-1/checkpoint-74064
# Configuration saved in ./electra-marian-training-1/checkpoint-74064/config.json
# Model weights saved in ./electra-marian-training-1/checkpoint-74064/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training-1/checkpoint-74064/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training-1/checkpoint-74064/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training-1/checkpoint-49376] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2280: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 53.14 and SacreBLEU of 52.48
# Saving model checkpoint to ./electra-marian-training-1/checkpoint-86408
# Configuration saved in ./electra-marian-training-1/checkpoint-86408/config.json
# Model weights saved in ./electra-marian-training-1/checkpoint-86408/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training-1/checkpoint-86408/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training-1/checkpoint-86408/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training-1/checkpoint-61720] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2280: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 53.69 and SacreBLEU of 53.00
# Saving model checkpoint to ./electra-marian-training-1/checkpoint-98752
# Configuration saved in ./electra-marian-training-1/checkpoint-98752/config.json
# Model weights saved in ./electra-marian-training-1/checkpoint-98752/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training-1/checkpoint-98752/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training-1/checkpoint-98752/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training-1/checkpoint-74064] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2280: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 54.97 and SacreBLEU of 54.34
# Saving model checkpoint to ./electra-marian-training-1/checkpoint-111096
# Configuration saved in ./electra-marian-training-1/checkpoint-111096/config.json
# Model weights saved in ./electra-marian-training-1/checkpoint-111096/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training-1/checkpoint-111096/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training-1/checkpoint-111096/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training-1/checkpoint-86408] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2280: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 54.89 and SacreBLEU of 54.25
# Saving model checkpoint to ./electra-marian-training-1/checkpoint-123440
# Configuration saved in ./electra-marian-training-1/checkpoint-123440/config.json
# Model weights saved in ./electra-marian-training-1/checkpoint-123440/pytorch_model.bin
# tokenizer config file saved in ./electra-marian-training-1/checkpoint-123440/tokenizer_config.json
# Special tokens file saved in ./electra-marian-training-1/checkpoint-123440/special_tokens_map.json
# Deleting older checkpoint [electra-marian-training-1/checkpoint-98752] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./electra-marian-training-1/checkpoint-123440 (score: 0.4879966378211975).
# TrainOutput(global_step=123440, training_loss=0.37785730022002717, metrics={'train_runtime': 17119.6856, 'train_samples_per_second': 14.42, 'train_steps_per_second': 7.21, 'total_flos': 3230087590379520.0, 'train_loss': 0.37785730022002717, 'epoch': 10.0})

# %%
trainer.save_model()
trainer.save_state()

# %% [markdown]
# # **Visualize**

# %%
# %load_ext tensorboard

# %% [markdown]
# ### **distilRoBERTa-marian**

# %%
tensorboard --logdir ./ELECTRA-marian-training1/runs/

# %% [markdown]
# # **Inference**

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
new_model = AutoModelForSeq2SeqLM.from_pretrained("./ELECTRA-marian-training1/")
new_model.to("cuda")

new_tokenizer = AutoTokenizer.from_pretrained("./ELECTRA-marian-training1/", use_fast=True)

# %%
new_model
# Out:
# EncoderDecoderModel(
#   (encoder): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (decoder): MarianForCausalLM(
#     (model): MarianDecoderWrapper(
#       (decoder): MarianDecoder(
#         (embed_tokens): Embedding(67028, 512, padding_idx=67027)
#         (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#         (layers): ModuleList(
#           (0): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (3): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (4): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (5): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (lm_head): Linear(in_features=512, out_features=67028, bias=False)
#   )
#   (enc_to_dec_proj): Linear(in_features=768, out_features=512, bias=True)
# )

# %%
new_model.config.max_length
# Out:
# 512

# %% [markdown]
# # **Evaluator**

# %%
# %cd Utils
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/CoNaLa/ELECTRA-Marian/Utils

# %%
from google.colab import files
import evaluator
evaluator = evaluator.CodeGenerationEvaluator(new_tokenizer, device,smooth_bleu=True)

# %%
batch_size = 1

# map data correctly
def generate_new_code(batch):
    inputs = new_tokenizer(batch["intent"], padding="max_length", truncation=True, max_length=512, return_tensors="pt")

    input_ids = inputs.input_ids.to("cuda")
    attention_mask = inputs.attention_mask.to("cuda")

    outputs = new_model.generate(input_ids, attention_mask=attention_mask)

    # all special tokens including will be removed
    output_str = new_tokenizer.batch_decode(outputs, skip_special_tokens=True)

    batch["pred_code"] = output_str

    return batch

# %%
results = test_dataset.map(generate_new_code, batched=True, batch_size=batch_size)

#results = test_dataset.map(generate_new_code, batched=True, batch_size=batch_size, remove_columns=["intent"])
# Out:
#   0%|          | 0/500 [00:00<?, ?ba/s]
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1268: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 512 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/CoNaLa/ELECTRA-Marian

# %%
import re
import string

import datasets
import numpy as np

import evaluate
from evaluate import load

# %%
exact_match = evaluate.load("exact_match")

#refs = ["The cat sat on the mat.", "Theaters are great.", "It's like comparing oranges and apples."]
#preds = ["The cat sat on the mat?", "Theaters are great.", "It's like comparing apples and oranges."]

"""
for i in range(len(results)):
  refs = results["code"][i]
  preds = results["pred_code"][i]
"""
# Out:
# Downloading builder script:   0%|          | 0.00/5.67k [00:00<?, ?B/s]
# '\nfor i in range(len(results)):\n  refs = results["code"][i]\n  preds = results["pred_code"][i]\n'

# %%
refs = results["snippet"]
preds = results["pred_code"]

# %%
exact_match_results = exact_match.compute(references=refs, predictions=preds, regexes_to_ignore=["▁", " "], ignore_case=True, ignore_punctuation=True, ignore_numbers=True)
print(round(exact_match_results["exact_match"], 5)*100)
# Out:
# 10.0

# %%
with open("./references.txt", 'w') as f:
  for i in range(len(results)):
    nl = results["intent"][i]
    ref = results["snippet"][i]
    pred = results["pred_code"][i]

    if pred is not None and pred != "":
      if ref is not None and ref != "":
        f.write(ref + '\n')
    else:
      continue


with open("./predictions.txt", 'w') as f:
  for i in range(len(results)):
    nl = results["intent"][i]
    ref = results["snippet"][i]
    pred = results["pred_code"][i]

    if pred is not None and pred != "":
      if ref is not None and ref != "":
        f.write(pred + '\n')
    else:
      continue

# %%
# Ok Evaluator
bleu_score =0
rouge_score = 0
sacre_bleu = 0

for i in range(len(results)):
  ref = results["snippet"][i]
  pred = results["pred_code"][i]
  if pred is not None and pred != "":
      if ref is not None and ref != "":
        #bleu_metric = metric.compute(predictions=[pred], references=[[ref]])
        #bleu_score  += bleu_metric["score"]

        bleu_metric = evaluator.evaluate([pred], [ref])
        #bleu_metric = evaluator.evaluateSingle(pred, ref)

        #bleu_score += bleu_metric['BLEU-Unigram-Precision']
        bleu_score += bleu_metric['BLEU']
        rouge_score += bleu_metric['ROUGE-L']
        sacre_bleu += bleu_metric['SacreBLEU']
        #print(bleu_metric['SacreBLEU'])
  else:
    continue

# %% [markdown]
# # **Performance Metrics**

# %% [markdown]
# **BLEU Score**

# %%
# electra-marian-training
print('Bleu Score: {} (scale 0-100)'.format(bleu_score/len(results)))
# Out:
# Bleu Score: 30.181939446068593 (scale 0-100)

# %% [markdown]
# **SacreBLEU**

# %%
print('Sacre Bleu: {} (scale 0-100)'.format(sacre_bleu/len(results)))
# Out:
# Sacre Bleu: 27.14954334532354 (scale 0-100)

# %% [markdown]
# **Rouge Score**

# %%
# electra-marian-training
print('ROUGE Score: {} (scale 0-100)'.format(rouge_score/len(results)))
# Out:
# ROUGE Score: 42.42324219505789 (scale 0-100)

# %% [markdown]
# **CodeBLEU**

# %%
from google.colab import files

# %%
import calc_code_bleu
ngram_match_score, weighted_ngram_match_score, syntax_match_score, dataflow_match_score, code_bleu_score = calc_code_bleu.calc_code_bleu("references.txt","predictions.txt","python", "keywords")

# %%
print("ngram_match_score: ", ngram_match_score*100)
print("weighted_ngram_match_score: ", weighted_ngram_match_score*100)
print("syntax_match_score: ", syntax_match_score*100)
print("dataflow_match_score: ", dataflow_match_score*100)
print("code_bleu_score: ", code_bleu_score*100)

# %% [markdown]
# # **Save the  results**

# %%
#%cd ..
# Out:
# /content/drive/MyDrive/models/CodeGeneration/MarianCG-CoNaLa-Large

# %%
bleu_score = 0
with open("./Output.txt", 'w') as f:
  for i in range(len(results)):
    nl = results["intent"][i]
    ref = results["snippet"][i]
    pred = results["pred_code"][i]

    if pred is not None and pred != "":
      if ref is not None and ref != "":

        bleu_metric = evaluator.evaluate([pred], [ref])
        f.write( "NL: " + nl + '\n')
        f.write( "ref: " + ref + '\n')
        f.write( "Output: " + pred + '\n')
        f.write("bleu_metric: " + str(bleu_metric["BLEU"]) + '\n')
        f.write(10*"-" + '\n')
        bleu_score  += bleu_metric["BLEU"]

    else:
      continue

# %% [markdown]
# # **Test**

# %%
# map data correctly
def generate_code(NL):
    inputs = new_tokenizer([NL], padding="max_length", truncation=True, max_length=512, return_tensors="pt")

    input_ids = inputs.input_ids.to("cuda")
    attention_mask = inputs.attention_mask.to("cuda")

    outputs = new_model.generate(input_ids, attention_mask=attention_mask)

    # all special tokens including will be removed
    output_code = new_tokenizer.batch_decode(outputs, skip_special_tokens=True)

    return output_code

# %%
#NL = "decode a hex string to utf-8."
NL = "remove first and last lines of string `s`"
output_code = generate_code(NL)

# %%
output_code

# %%
natural_language = "How I can get rid of None values in dictionary?"
gen_code = generate_code(natural_language)

# %%
gen_code
