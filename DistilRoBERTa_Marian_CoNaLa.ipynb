# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedSSoliman/Leveraging-Pretrained-Language-Models-for-Code-Generation/blob/master/DistilRoBERTa_Marian_CoNaLa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import torch
torch.cuda.empty_cache()

# %% [markdown]
# # **Install dependencies**

# %%
# %%capture
# !pip install tensorflow
# !pip install keras
# !pip install netron
# !pip install nltk

# !pip install git+https://github.com/huggingface/transformers
# !pip install datasets
# !pip install nlp
# !pip install rouge-score
#!pip install sacrebleu
# !pip install git-python
# !pip install sentencepiece
#!pip install torchdata
#!pip install transformers
# !pip install sacrebleu==1.5.1
# !pip install tree-sitter
# !pip install evaluate

# %% [markdown]
# # **Import Libraries**

# %%
import transformers
import datasets
from datasets import load_dataset, load_metric
import logging
from transformers import BertTokenizer, GPT2Tokenizer, GPT2TokenizerFast, EncoderDecoderModel, Trainer, TrainingArguments, BertTokenizerFast
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments
from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer

logging.basicConfig(level=logging.INFO)

import types
import argparse
import logging
from functools import partial
import json

import torch
from torch import optim
from torch.utils.data import DataLoader
from tqdm import tqdm
from transformers import (
    BertGenerationConfig,
    BertGenerationEncoder,
    BertTokenizer,
    EncoderDecoderModel,
    EncoderDecoderConfig,
    GPT2LMHeadModel,
    GPT2TokenizerFast,
    Trainer,
    TrainingArguments,
    get_cosine_schedule_with_warmup,
)

import sacrebleu
import random
import numpy as np
#from tensorboardX import SummaryWriter

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
# %cd /content/drive/MyDrive/models/CodeGeneration/New/CoNaLa/distilRoBERTa-Marian
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/CoNaLa/distilRoBERTa-Marian

# %% [markdown]
# # **Load Data**

# %%
from datasets import load_dataset

raw_dataset = load_dataset("AhmedSSoliman/CoNaLa-Large")
# Out:
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_deprecation.py:97: FutureWarning: Deprecated argument(s) used in 'dataset_info': token. Will not be supported from version '0.12'.
#   warnings.warn(message, FutureWarning)
# WARNING:datasets.builder:Using custom data configuration AhmedSSoliman--CoNaLa-Large-87e6f6b36beed736
# Downloading and preparing dataset csv/AhmedSSoliman--CoNaLa-Large to /root/.cache/huggingface/datasets/AhmedSSoliman___csv/AhmedSSoliman--CoNaLa-Large-87e6f6b36beed736/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/2.32M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/51.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/117k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/AhmedSSoliman___csv/AhmedSSoliman--CoNaLa-Large-87e6f6b36beed736/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
train_dataset= raw_dataset["train"]
val_dataset = raw_dataset["validation"]
test_dataset = raw_dataset["test"]

# %%
raw_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['intent', 'snippet'],
#         num_rows: 24687
#     })
#     test: Dataset({
#         features: ['intent', 'snippet'],
#         num_rows: 500
#     })
#     validation: Dataset({
#         features: ['intent', 'snippet'],
#         num_rows: 1237
#     })
# })

# %% [markdown]
# # **Tokenizer**

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("distilroberta-base", use_fast = True)
tokenizer
# "Helsinki-NLP/opus-mt-en-nl"
# "distilroberta-base"
##### "studio-ousia/luke-base"
#"AhmedSSoliman/MarianCG_NL-to-Code"
#"distilbert-base-uncased"
#studio-ousia/mluke-base-lite
# "google/electra-small-discriminator"
#"bert-base-uncased"
#"microsoft/deberta-v3-xsmall"
#"microsoft/deberta-v3-base"
# "xlnet-base-cased"
#"google/fnet-base"
#"google/bigbird-roberta-base"
# Out:
# Downloading:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# PreTrainedTokenizerFast(name_or_path='distilroberta-base', vocab_size=50265, model_max_len=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'sep_token': '</s>', 'pad_token': '<pad>', 'cls_token': '<s>', 'mask_token': AddedToken("<mask>", rstrip=False, lstrip=True, single_word=False, normalized=False)})

# %% [markdown]
# # **Model**

# %%
model = EncoderDecoderModel.from_encoder_decoder_pretrained("distilroberta-base", "Helsinki-NLP/opus-mt-en-nl")
model
# Out:
# Downloading:   0%|          | 0.00/331M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/316M [00:00<?, ?B/s]
# Some weights of the model checkpoint at Helsinki-NLP/opus-mt-en-nl were not used when initializing MarianForCausalLM: ['model.encoder.layers.2.self_attn_layer_norm.weight', 'model.encoder.layers.3.self_attn.k_proj.weight', 'model.encoder.layers.2.self_attn.k_proj.weight', 'model.encoder.layers.2.fc2.weight', 'model.encoder.layers.5.fc2.weight', 'model.encoder.layers.4.final_layer_norm.bias', 'model.encoder.layers.1.self_attn.k_proj.bias', 'model.encoder.layers.0.self_attn.out_proj.bias', 'model.encoder.layers.4.fc1.bias', 'model.encoder.layers.0.self_attn.v_proj.bias', 'model.encoder.layers.2.self_attn.v_proj.bias', 'model.encoder.layers.2.self_attn.k_proj.bias', 'model.encoder.layers.5.self_attn.v_proj.bias', 'model.encoder.layers.1.self_attn.v_proj.bias', 'model.encoder.layers.3.fc1.bias', 'model.encoder.layers.1.fc2.weight', 'model.encoder.embed_positions.weight', 'model.encoder.layers.5.self_attn.out_proj.weight', 'model.encoder.layers.5.fc2.bias', 'model.encoder.layers.4.self_attn.out_proj.weight', 'model.encoder.layers.2.final_layer_norm.bias', 'model.encoder.layers.5.fc1.weight', 'model.encoder.layers.4.self_attn_layer_norm.weight', 'model.encoder.layers.1.fc2.bias', 'model.encoder.layers.5.self_attn.out_proj.bias', 'model.encoder.layers.1.self_attn_layer_norm.bias', 'model.encoder.layers.3.self_attn.v_proj.weight', 'model.encoder.layers.3.self_attn_layer_norm.bias', 'model.encoder.layers.4.self_attn.q_proj.weight', 'model.encoder.layers.4.self_attn.v_proj.bias', 'model.encoder.layers.1.final_layer_norm.bias', 'model.encoder.layers.4.self_attn.k_proj.bias', 'model.encoder.layers.4.self_attn_layer_norm.bias', 'model.encoder.layers.3.fc2.weight', 'model.encoder.layers.4.self_attn.v_proj.weight', 'model.encoder.layers.0.self_attn.k_proj.bias', 'model.encoder.layers.0.final_layer_norm.bias', 'model.encoder.layers.1.self_attn.out_proj.bias', 'model.encoder.layers.0.final_layer_norm.weight', 'model.encoder.layers.1.final_layer_norm.weight', 'model.encoder.layers.2.final_layer_norm.weight', 'model.encoder.layers.0.self_attn_layer_norm.bias', 'model.encoder.layers.1.self_attn_layer_norm.weight', 'model.encoder.layers.2.fc1.weight', 'model.encoder.layers.2.self_attn.q_proj.bias', 'model.encoder.layers.3.self_attn.q_proj.weight', 'model.encoder.layers.4.self_attn.k_proj.weight', 'model.encoder.layers.5.self_attn_layer_norm.weight', 'model.encoder.layers.2.self_attn.out_proj.bias', 'model.encoder.layers.0.self_attn.q_proj.bias', 'model.encoder.layers.5.self_attn.v_proj.weight', 'model.encoder.layers.0.self_attn.k_proj.weight', 'model.encoder.layers.3.fc2.bias', 'model.encoder.layers.3.self_attn.out_proj.weight', 'model.encoder.layers.1.self_attn.out_proj.weight', 'model.encoder.layers.0.self_attn.out_proj.weight', 'model.encoder.layers.3.final_layer_norm.bias', 'model.encoder.layers.3.self_attn.k_proj.bias', 'model.encoder.layers.5.self_attn.k_proj.weight', 'model.encoder.layers.5.self_attn.q_proj.weight', 'model.shared.weight', 'model.encoder.layers.3.self_attn.out_proj.bias', 'model.encoder.layers.5.final_layer_norm.weight', 'model.encoder.layers.1.fc1.weight', 'model.encoder.layers.2.self_attn.q_proj.weight', 'model.encoder.layers.3.fc1.weight', 'model.encoder.layers.4.final_layer_norm.weight', 'model.encoder.layers.5.self_attn.q_proj.bias', 'model.encoder.layers.1.self_attn.q_proj.weight', 'model.encoder.layers.0.fc2.bias', 'model.encoder.layers.1.fc1.bias', 'model.encoder.layers.0.fc2.weight', 'model.encoder.layers.2.self_attn_layer_norm.bias', 'model.encoder.layers.5.final_layer_norm.bias', 'model.encoder.layers.3.self_attn_layer_norm.weight', 'model.encoder.layers.4.fc2.bias', 'model.encoder.layers.0.self_attn.q_proj.weight', 'model.encoder.layers.0.self_attn.v_proj.weight', 'model.encoder.layers.2.self_attn.v_proj.weight', 'model.encoder.layers.5.self_attn_layer_norm.bias', 'model.encoder.layers.1.self_attn.k_proj.weight', 'model.encoder.embed_tokens.weight', 'model.encoder.layers.4.fc2.weight', 'model.encoder.layers.5.sel ...
# - This IS expected if you are initializing MarianForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing MarianForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of MarianForCausalLM were not initialized from the model checkpoint at Helsinki-NLP/opus-mt-en-nl and are newly initialized: ['lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# EncoderDecoderModel(
#   (encoder): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): RobertaPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (decoder): MarianForCausalLM(
#     (model): MarianDecoderWrapper(
#       (decoder): MarianDecoder(
#         (embed_tokens): Embedding(67028, 512, padding_idx=67027)
#         (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#         (layers): ModuleList(
#           (0): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (3): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (4): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (5): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (lm_head): Linear(in_features=512, out_features=67028, bias=False)
#   )
#   (enc_to_dec_proj): Linear(in_features=768, out_features=512, bias=True)
# )

# %%
model.config
# Out:
# EncoderDecoderConfig {
#   "_commit_hash": null,
#   "decoder": {
#     "_name_or_path": "Helsinki-NLP/opus-mt-en-nl",
#     "_num_labels": 3,
#     "activation_dropout": 0.0,
#     "activation_function": "swish",
#     "add_bias_logits": false,
#     "add_cross_attention": true,
#     "add_final_layer_norm": false,
#     "architectures": [
#       "MarianMTModel"
#     ],
#     "attention_dropout": 0.0,
#     "bad_words_ids": [
#       [
#         67027
#       ]
#     ],
#     "bos_token_id": 0,
#     "chunk_size_feed_forward": 0,
#     "classif_dropout": 0.0,
#     "classifier_dropout": 0.0,
#     "cross_attention_hidden_size": null,
#     "d_model": 512,
#     "decoder_attention_heads": 8,
#     "decoder_ffn_dim": 2048,
#     "decoder_layerdrop": 0.0,
#     "decoder_layers": 6,
#     "decoder_start_token_id": 67027,
#     "decoder_vocab_size": 67028,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "dropout": 0.1,
#     "early_stopping": false,
#     "encoder_attention_heads": 8,
#     "encoder_ffn_dim": 2048,
#     "encoder_layerdrop": 0.0,
#     "encoder_layers": 6,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": 0,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": 0,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1",
#       "2": "LABEL_2"
#     },
#     "init_std": 0.02,
#     "is_decoder": true,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1,
#       "LABEL_2": 2
#     },
#     "length_penalty": 1.0,
#     "max_length": 512,
#     "max_position_embeddings": 512,
#     "min_length": 0,
#     "model_type": "marian",
#     "no_repeat_ngram_size": 0,
#     "normalize_before": false,
#     "normalize_embedding": false,
#     "num_beam_groups": 1,
#     "num_beams": 4,
#     "num_hidden_layers": 6,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": 67027,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "scale_embedding": true,
#     "sep_token_id": null,
#     "share_encoder_decoder_embeddings": true,
#     "static_position_embeddings": true,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": null,
#     "torchscript": false,
#     "transformers_version": "4.22.0.dev0",
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "vocab_size": 67028
#   },
#   "encoder": {
#     "_name_or_path": "distilroberta-base",
#     "add_cross_attention": false,
#     "architectures": [
#       "RobertaForMaskedLM"
#     ],
#     "attention_probs_dropout_prob": 0.1,
#     "bad_words_ids": null,
#     "bos_token_id": 0,
#     "chunk_size_feed_forward": 0,
#     "classifier_dropout": null,
#     "cross_attention_hidden_size": null,
#     "decoder_start_token_id": null,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "early_stopping": false,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": 2,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 768,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "initializer_range": 0.02,
#     "intermediate_size": 3072,
#     "is_decoder": false,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "layer_norm_eps": 1e-05,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "max_position_embeddings": 514,
#     "min_length": 0,
#     "model_type": "roberta",
#     "no_repeat_ngram_size": 0,
#     "num_attention_heads": 12,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_hidden_layers": 6,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": 1,
#     "position_embedding_type": "absolute",
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "sep_token_id": null,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": null,
#     "torchscript": false,
#     "transformers_version": "4.22.0.dev0",
#     "type_vocab_size": 1,
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "vocab_size": 50265
#   },
#   "is_encoder_decoder": true,
#   "model_type": "encoder-decoder",
#   "transformers_version": null
# }

# %%
model.base_model.config.encoder.num_hidden_layers = 6
# Out:
# 6

# %%
model.tie_weights = True

# %%
model.base_model.config.decoder_start_token_id = model.base_model.config.decoder.bos_token_id

# %%
model.base_model.config.bos_token_id = tokenizer.bos_token_id
model.base_model.config.eos_token_id = tokenizer.eos_token_id
model.base_model.config.pad_token_id = tokenizer.pad_token_id

# %%
model.config.max_length =512

# %%
model.save_pretrained("distilRoBERTa-Marian-base-model")

# %%
from transformers import AutoModelForSeq2SeqLM
model = AutoModelForSeq2SeqLM.from_pretrained("./distilRoBERTa-Marian-base-model")
#model=AutoModelForSeq2SeqLM.from_pretrained("./distilroberta-marian-training")
model
# Out:
# EncoderDecoderModel(
#   (encoder): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): RobertaPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (decoder): MarianForCausalLM(
#     (model): MarianDecoderWrapper(
#       (decoder): MarianDecoder(
#         (embed_tokens): Embedding(67028, 512, padding_idx=67027)
#         (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#         (layers): ModuleList(
#           (0): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (3): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (4): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (5): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (lm_head): Linear(in_features=512, out_features=67028, bias=False)
#   )
#   (enc_to_dec_proj): Linear(in_features=768, out_features=512, bias=True)
# )

# %%
model.base_model.config.decoder_start_token_id
# Out:
# 0

# %%
model.base_model.config.pad_token_id
# Out:
# 1

# %%
tokenizer.pad_token_id
# Out:
# 1

# %%
model.config
# Out:
# EncoderDecoderConfig {
#   "_commit_hash": null,
#   "_name_or_path": "./distilRoBERTa-Marian--base-model",
#   "architectures": [
#     "EncoderDecoderModel"
#   ],
#   "bos_token_id": 0,
#   "decoder": {
#     "_name_or_path": "Helsinki-NLP/opus-mt-en-nl",
#     "_num_labels": 3,
#     "activation_dropout": 0.0,
#     "activation_function": "swish",
#     "add_bias_logits": false,
#     "add_cross_attention": true,
#     "add_final_layer_norm": false,
#     "architectures": [
#       "MarianMTModel"
#     ],
#     "attention_dropout": 0.0,
#     "bad_words_ids": [
#       [
#         67027
#       ]
#     ],
#     "bos_token_id": 0,
#     "chunk_size_feed_forward": 0,
#     "classif_dropout": 0.0,
#     "classifier_dropout": 0.0,
#     "cross_attention_hidden_size": null,
#     "d_model": 512,
#     "decoder_attention_heads": 8,
#     "decoder_ffn_dim": 2048,
#     "decoder_layerdrop": 0.0,
#     "decoder_layers": 6,
#     "decoder_start_token_id": 67027,
#     "decoder_vocab_size": 67028,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "dropout": 0.1,
#     "early_stopping": false,
#     "encoder_attention_heads": 8,
#     "encoder_ffn_dim": 2048,
#     "encoder_layerdrop": 0.0,
#     "encoder_layers": 6,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": 0,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": 0,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1",
#       "2": "LABEL_2"
#     },
#     "init_std": 0.02,
#     "is_decoder": true,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1,
#       "LABEL_2": 2
#     },
#     "length_penalty": 1.0,
#     "max_length": 512,
#     "max_position_embeddings": 512,
#     "min_length": 0,
#     "model_type": "marian",
#     "no_repeat_ngram_size": 0,
#     "normalize_before": false,
#     "normalize_embedding": false,
#     "num_beam_groups": 1,
#     "num_beams": 4,
#     "num_hidden_layers": 6,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": 67027,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "scale_embedding": true,
#     "sep_token_id": null,
#     "share_encoder_decoder_embeddings": true,
#     "static_position_embeddings": true,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": null,
#     "torchscript": false,
#     "transformers_version": "4.22.0.dev0",
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "vocab_size": 67028
#   },
#   "decoder_start_token_id": 0,
#   "encoder": {
#     "_name_or_path": "distilroberta-base",
#     "add_cross_attention": false,
#     "architectures": [
#       "RobertaForMaskedLM"
#     ],
#     "attention_probs_dropout_prob": 0.1,
#     "bad_words_ids": null,
#     "bos_token_id": 0,
#     "chunk_size_feed_forward": 0,
#     "classifier_dropout": null,
#     "cross_attention_hidden_size": null,
#     "decoder_start_token_id": null,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "early_stopping": false,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": 2,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 768,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "initializer_range": 0.02,
#     "intermediate_size": 3072,
#     "is_decoder": false,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "layer_norm_eps": 1e-05,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "max_position_embeddings": 514,
#     "min_length": 0,
#     "model_type": "roberta",
#     "no_repeat_ngram_size": 0,
#     "num_attention_heads": 12,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_hidden_layers": 6,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": 1,
#     "position_embedding_type": "absolute",
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "sep_token_id": null,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": null,
#     "torchscript": false,
#     "transformers_version": "4.22.0.dev0",
#     "type_vocab_size": 1,
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "vocab_size": 50265
#   },
#   "eos_token_id": 2,
#   "is_encoder_decoder": true,
#   "max_length": 512,
#   "model_type": "encoder-decoder",
#   "pad_token_id": 1,
#   "torch_dtype": "float32",
#   "transformers_version": null
# }

# %% [markdown]
# # **Evaluator**

# %%
# %cd Utils
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/CoNaLa/distilRoBERTa-Marian/Utils

# %%
from google.colab import files
import evaluator
evaluator = evaluator.CodeGenerationEvaluator(tokenizer, device,smooth_bleu=True)
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/CoNaLa/distilRoBERTa-Marian/Utils/evaluator.py:32: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   self.sacre_bleu: Metric = load_metric('sacrebleu')
# Downloading builder script:   0%|          | 0.00/2.85k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.48k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.16k [00:00<?, ?B/s]

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/CoNaLa/distilRoBERTa-Marian

# %% [markdown]
# # **Prepare the data.**

# %%
encoder_length = 32
decoder_length = 32
batch_size = 1


# map data correctly
def map_to_encoder_decoder_inputs(batch):
    inputs = tokenizer(batch["intent"], padding="max_length", truncation=True, max_length=encoder_length)
    outputs = tokenizer(batch["snippet"], padding="max_length", truncation=True, max_length=decoder_length)
    batch["input_ids"] = inputs.input_ids
    batch["attention_mask"] = inputs.attention_mask
    batch["decoder_input_ids"] = outputs.input_ids
    batch["labels"] = outputs.input_ids.copy()
    batch["decoder_attention_mask"] = outputs.attention_mask

    """
    # complicated list comprehension here because pad_token_id alone is not good enough to know whether label should be excluded or not
    batch["labels"] = [
        [-100 if mask == 0 else token for mask, token in mask_and_tokens] for mask_and_tokens in [zip(masks, labels) for masks, labels in zip(batch["decoder_attention_mask"], batch["labels"])]
    ]
    """
    assert all([len(x) == encoder_length for x in inputs.input_ids])
    assert all([len(x) == decoder_length for x in outputs.input_ids])

    return batch

# %%
# make train dataset ready
train_data = train_dataset.map(
    map_to_encoder_decoder_inputs, batched=True, batch_size=1, remove_columns=['intent', 'snippet'],
)
train_data.set_format(
    type="torch", columns=["input_ids", "attention_mask", "decoder_input_ids", "decoder_attention_mask", "labels"],
)
# Out:
#   0%|          | 0/24687 [00:00<?, ?ba/s]

# %%
# same for validation dataset
val_data = val_dataset.map(
    map_to_encoder_decoder_inputs, batched=True, batch_size=1, remove_columns=['intent', 'snippet'],
)
val_data.set_format(
    type="torch", columns=["input_ids", "attention_mask", "decoder_input_ids", "decoder_attention_mask", "labels"],
)
# Out:
#   0%|          | 0/1237 [00:00<?, ?ba/s]

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer,
                                       max_length=512,padding=True, ####new
                                       model = model)

# %% [markdown]
# # **Training**

# %%
# set training arguments - these params are not really tuned, feel free to change
training_args = Seq2SeqTrainingArguments(
    output_dir="./distilroberta-marian-training",
    evaluation_strategy="epoch",
    save_strategy = "epoch",
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    predict_with_generate=True,
    num_train_epochs=10,
    do_train=True,
    do_eval=True,
    fp16=True,
    overwrite_output_dir=True,
    learning_rate = 1e-5,
    weight_decay=0.01,
    warmup_ratio = 0.05,
    seed = 1995,
    save_total_limit = 2,
    load_best_model_at_end = True,
    #push_to_hub=True,
)
#

# instantiate trainer
trainer = Seq2SeqTrainer(
    model=model,
    tokenizer=tokenizer,
    args=training_args,
    compute_metrics=evaluator,
    data_collator = data_collator,
    train_dataset=train_data,
    eval_dataset =val_data,

)
#    save_total_limit=3,
#
# Out:
# Using cuda_amp half precision backend

# %%
# distilRoBERTa-Marian-Training
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 24687
#   Num Epochs = 15
#   Instantaneous batch size per device = 2
#   Total train batch size (w. parallel, distributed & accumulation) = 2
#   Gradient Accumulation steps = 1
#   Total optimization steps = 185160
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
#     <div>
#
#       <progress value='127397' max='185160' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [127397/185160 4:29:00 < 2:01:58, 7.89 it/s, Epoch 10.32/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Sacrebleu</th>
#       <th>Bleu-unigram-precision</th>
#       <th>Bleu-bigram-precision</th>
#       <th>Bleu-trigram-precision</th>
#       <th>Rouge-2</th>
#       <th>Rouge-l</th>
#       <th>Sacre-unigram-precision</th>
#       <th>Sacre-bigram-precision</th>
#       <th>Sacre-trigram-precision</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.007100</td>
#       <td>1.917734</td>
#       <td>6.089487</td>
#       <td>4.947906</td>
#       <td>24.776739</td>
#       <td>9.272330</td>
#       <td>3.407614</td>
#       <td>6.651839</td>
#       <td>17.882538</td>
#       <td>20.454028</td>
#       <td>6.890851</td>
#       <td>2.871239</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.504700</td>
#       <td>1.486641</td>
#       <td>11.866654</td>
#       <td>10.589252</td>
#       <td>37.520175</td>
#       <td>16.021111</td>
#       <td>7.349348</td>
#       <td>8.715316</td>
#       <td>20.726921</td>
#       <td>34.049287</td>
#       <td>13.227372</td>
#       <td>6.690539</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.321200</td>
#       <td>1.275110</td>
#       <td>15.074518</td>
#       <td>14.028332</td>
#       <td>40.000827</td>
#       <td>19.263777</td>
#       <td>10.106824</td>
#       <td>11.965103</td>
#       <td>25.095416</td>
#       <td>37.141518</td>
#       <td>16.711651</td>
#       <td>9.660363</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.136100</td>
#       <td>1.132923</td>
#       <td>19.793712</td>
#       <td>18.158199</td>
#       <td>48.722325</td>
#       <td>26.138195</td>
#       <td>14.990064</td>
#       <td>14.271862</td>
#       <td>28.416362</td>
#       <td>45.755581</td>
#       <td>22.930507</td>
#       <td>14.304247</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.951900</td>
#       <td>1.030566</td>
#       <td>23.376455</td>
#       <td>21.980032</td>
#       <td>49.490420</td>
#       <td>28.248560</td>
#       <td>17.680967</td>
#       <td>17.497598</td>
#       <td>31.315467</td>
#       <td>46.764278</td>
#       <td>25.448386</td>
#       <td>17.202018</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.845400</td>
#       <td>0.947849</td>
#       <td>27.993576</td>
#       <td>26.622312</td>
#       <td>53.086809</td>
#       <td>32.443404</td>
#       <td>21.948124</td>
#       <td>21.575308</td>
#       <td>35.581860</td>
#       <td>50.590707</td>
#       <td>29.903856</td>
#       <td>21.540573</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.777100</td>
#       <td>0.879183</td>
#       <td>30.281223</td>
#       <td>29.087174</td>
#       <td>54.857349</td>
#       <td>34.821898</td>
#       <td>24.208547</td>
#       <td>24.095648</td>
#       <td>38.536785</td>
#       <td>52.397085</td>
#       <td>32.387986</td>
#       <td>23.808525</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.662500</td>
#       <td>0.830730</td>
#       <td>33.166844</td>
#       <td>32.041068</td>
#       <td>56.926781</td>
#       <td>37.672650</td>
#       <td>27.392283</td>
#       <td>27.057785</td>
#       <td>40.873964</td>
#       <td>54.404121</td>
#       <td>35.207523</td>
#       <td>26.836173</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.646000</td>
#       <td>0.791341</td>
#       <td>36.115456</td>
#       <td>34.859708</td>
#       <td>59.368594</td>
#       <td>40.619871</td>
#       <td>30.465140</td>
#       <td>29.274882</td>
#       <td>42.885528</td>
#       <td>57.334087</td>
#       <td>38.535462</td>
#       <td>30.140860</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.581800</td>
#       <td>0.757475</td>
#       <td>38.893631</td>
#       <td>37.687065</td>
#       <td>61.092768</td>
#       <td>42.971445</td>
#       <td>33.099058</td>
#       <td>32.234142</td>
#       <td>45.450288</td>
#       <td>59.065883</td>
#       <td>40.960634</td>
#       <td>32.751345</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 6.09 and SacreBLEU of 4.95
# Saving model checkpoint to ./distilRoBERTa-Marian-Training/checkpoint-12344
# Configuration saved in ./distilRoBERTa-Marian-Training/checkpoint-12344/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training/checkpoint-12344/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training/checkpoint-12344/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training/checkpoint-12344/special_tokens_map.json
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 11.87 and SacreBLEU of 10.59
# Saving model checkpoint to ./distilRoBERTa-Marian-Training/checkpoint-24688
# Configuration saved in ./distilRoBERTa-Marian-Training/checkpoint-24688/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training/checkpoint-24688/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training/checkpoint-24688/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training/checkpoint-24688/special_tokens_map.json
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 15.07 and SacreBLEU of 14.03
# Saving model checkpoint to ./distilRoBERTa-Marian-Training/checkpoint-37032
# Configuration saved in ./distilRoBERTa-Marian-Training/checkpoint-37032/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training/checkpoint-37032/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training/checkpoint-37032/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training/checkpoint-37032/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training/checkpoint-12344] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 19.79 and SacreBLEU of 18.16
# Saving model checkpoint to ./distilRoBERTa-Marian-Training/checkpoint-49376
# Configuration saved in ./distilRoBERTa-Marian-Training/checkpoint-49376/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training/checkpoint-49376/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training/checkpoint-49376/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training/checkpoint-49376/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training/checkpoint-24688] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 23.38 and SacreBLEU of 21.98
# Saving model checkpoint to ./distilRoBERTa-Marian-Training/checkpoint-61720
# Configuration saved in ./distilRoBERTa-Marian-Training/checkpoint-61720/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training/checkpoint-61720/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training/checkpoint-61720/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training/checkpoint-61720/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training/checkpoint-37032] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 27.99 and SacreBLEU of 26.62
# Saving model checkpoint to ./distilRoBERTa-Marian-Training/checkpoint-74064
# Configuration saved in ./distilRoBERTa-Marian-Training/checkpoint-74064/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training/checkpoint-74064/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training/checkpoint-74064/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training/checkpoint-74064/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training/checkpoint-49376] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 30.28 and SacreBLEU of 29.09
# Saving model checkpoint to ./distilRoBERTa-Marian-Training/checkpoint-86408
# Configuration saved in ./distilRoBERTa-Marian-Training/checkpoint-86408/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training/checkpoint-86408/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training/checkpoint-86408/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training/checkpoint-86408/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training/checkpoint-61720] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 33.17 and SacreBLEU of 32.04
# Saving model checkpoint to ./distilRoBERTa-Marian-Training/checkpoint-98752
# Configuration saved in ./distilRoBERTa-Marian-Training/checkpoint-98752/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training/checkpoint-98752/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training/checkpoint-98752/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training/checkpoint-98752/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training/checkpoint-74064] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 36.12 and SacreBLEU of 34.86
# Saving model checkpoint to ./distilRoBERTa-Marian-Training/checkpoint-111096
# Configuration saved in ./distilRoBERTa-Marian-Training/checkpoint-111096/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training/checkpoint-111096/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training/checkpoint-111096/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training/checkpoint-111096/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training/checkpoint-86408] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 38.89 and SacreBLEU of 37.69
# Saving model checkpoint to ./distilRoBERTa-Marian-Training/checkpoint-123440
# Configuration saved in ./distilRoBERTa-Marian-Training/checkpoint-123440/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training/checkpoint-123440/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training/checkpoint-123440/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training/checkpoint-123440/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training/checkpoint-98752] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-96d1118ab1ef> in <module>()
#       1 # distilRoBERTa-Marian-Training
# ----> 2 trainer.train()
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1416                         tr_loss_step = self.training_step(model, inputs)
#    1417                 else:
# -> 1418                     tr_loss_step = self.training_step(model, inputs)
#    1419
#    1420                 if (
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in training_step(self, model, inputs)
#    2015
#    2016         if self.do_grad_scaling:
# -> 2017             self.scaler.scale(loss).backward()
#    2018         elif self.use_apex:
#    2019             with amp.scale_loss(loss, self.optimizer) as scaled_loss:
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     157
#     158
#
# KeyboardInterrupt:

# %%
# distilRoBERTa-Marian-Training-1
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 24687
#   Num Epochs = 15
#   Instantaneous batch size per device = 2
#   Total train batch size (w. parallel, distributed & accumulation) = 2
#   Gradient Accumulation steps = 1
#   Total optimization steps = 185160
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
#     <div>
#
#       <progress value='185160' max='185160' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [185160/185160 4:41:35, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Sacrebleu</th>
#       <th>Bleu-unigram-precision</th>
#       <th>Bleu-bigram-precision</th>
#       <th>Bleu-trigram-precision</th>
#       <th>Rouge-2</th>
#       <th>Rouge-l</th>
#       <th>Sacre-unigram-precision</th>
#       <th>Sacre-bigram-precision</th>
#       <th>Sacre-trigram-precision</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.560500</td>
#       <td>0.759882</td>
#       <td>39.178874</td>
#       <td>37.892805</td>
#       <td>61.227260</td>
#       <td>43.190643</td>
#       <td>33.442038</td>
#       <td>32.557061</td>
#       <td>45.860162</td>
#       <td>59.189391</td>
#       <td>41.062491</td>
#       <td>33.035950</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.479200</td>
#       <td>0.709103</td>
#       <td>40.242731</td>
#       <td>39.046538</td>
#       <td>64.244560</td>
#       <td>46.362072</td>
#       <td>36.633022</td>
#       <td>34.676962</td>
#       <td>47.621424</td>
#       <td>62.238689</td>
#       <td>44.213991</td>
#       <td>36.260054</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.469000</td>
#       <td>0.674257</td>
#       <td>44.352946</td>
#       <td>43.257314</td>
#       <td>65.919806</td>
#       <td>49.455068</td>
#       <td>40.382078</td>
#       <td>39.453178</td>
#       <td>51.453299</td>
#       <td>64.303993</td>
#       <td>47.745712</td>
#       <td>40.346548</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.389800</td>
#       <td>0.638110</td>
#       <td>46.646363</td>
#       <td>45.663731</td>
#       <td>66.183112</td>
#       <td>50.555985</td>
#       <td>41.806777</td>
#       <td>40.526679</td>
#       <td>52.712707</td>
#       <td>64.262985</td>
#       <td>48.686237</td>
#       <td>41.503942</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.318400</td>
#       <td>0.614325</td>
#       <td>47.481972</td>
#       <td>46.357521</td>
#       <td>68.421300</td>
#       <td>52.719478</td>
#       <td>44.174680</td>
#       <td>42.339843</td>
#       <td>54.173485</td>
#       <td>66.719953</td>
#       <td>50.994538</td>
#       <td>43.951569</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.291500</td>
#       <td>0.585153</td>
#       <td>51.234245</td>
#       <td>50.220265</td>
#       <td>69.955899</td>
#       <td>55.199454</td>
#       <td>47.170105</td>
#       <td>45.228799</td>
#       <td>56.957199</td>
#       <td>68.419808</td>
#       <td>53.742590</td>
#       <td>46.933419</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.267700</td>
#       <td>0.562906</td>
#       <td>52.902339</td>
#       <td>52.081580</td>
#       <td>70.002689</td>
#       <td>55.739027</td>
#       <td>47.645932</td>
#       <td>47.268497</td>
#       <td>58.821163</td>
#       <td>68.476614</td>
#       <td>54.184915</td>
#       <td>47.325636</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.227100</td>
#       <td>0.542791</td>
#       <td>54.248125</td>
#       <td>53.411113</td>
#       <td>72.236539</td>
#       <td>58.307715</td>
#       <td>50.545285</td>
#       <td>48.675929</td>
#       <td>59.886669</td>
#       <td>70.587405</td>
#       <td>56.599530</td>
#       <td>50.181121</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.220700</td>
#       <td>0.530568</td>
#       <td>55.284456</td>
#       <td>54.387091</td>
#       <td>72.951008</td>
#       <td>59.356440</td>
#       <td>51.561772</td>
#       <td>49.785676</td>
#       <td>60.690415</td>
#       <td>71.525680</td>
#       <td>57.928511</td>
#       <td>51.453768</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.198700</td>
#       <td>0.515304</td>
#       <td>56.708361</td>
#       <td>55.837988</td>
#       <td>74.559778</td>
#       <td>61.357715</td>
#       <td>53.650495</td>
#       <td>51.599450</td>
#       <td>62.424221</td>
#       <td>73.212075</td>
#       <td>59.926136</td>
#       <td>53.464652</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.207200</td>
#       <td>0.503921</td>
#       <td>58.028912</td>
#       <td>57.195424</td>
#       <td>74.231904</td>
#       <td>61.366478</td>
#       <td>53.997546</td>
#       <td>52.254440</td>
#       <td>63.106436</td>
#       <td>72.881277</td>
#       <td>60.004938</td>
#       <td>53.681498</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.195800</td>
#       <td>0.495879</td>
#       <td>57.862468</td>
#       <td>57.169010</td>
#       <td>74.015317</td>
#       <td>61.423257</td>
#       <td>54.167095</td>
#       <td>52.511843</td>
#       <td>62.956816</td>
#       <td>72.603826</td>
#       <td>60.020799</td>
#       <td>53.935429</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.176800</td>
#       <td>0.489294</td>
#       <td>59.138901</td>
#       <td>58.254094</td>
#       <td>75.302586</td>
#       <td>62.979344</td>
#       <td>55.869273</td>
#       <td>53.496065</td>
#       <td>63.849336</td>
#       <td>73.998588</td>
#       <td>61.560376</td>
#       <td>55.569762</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.157100</td>
#       <td>0.484331</td>
#       <td>58.771248</td>
#       <td>57.962860</td>
#       <td>74.597471</td>
#       <td>62.075281</td>
#       <td>55.017425</td>
#       <td>53.531043</td>
#       <td>63.841770</td>
#       <td>73.237403</td>
#       <td>60.641399</td>
#       <td>54.631579</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.164100</td>
#       <td>0.481315</td>
#       <td>58.696414</td>
#       <td>57.921365</td>
#       <td>74.973640</td>
#       <td>62.446540</td>
#       <td>55.390661</td>
#       <td>53.763988</td>
#       <td>63.938110</td>
#       <td>73.599173</td>
#       <td>61.050165</td>
#       <td>55.109741</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 39.18 and SacreBLEU of 37.89
# Saving model checkpoint to ./distilRoBERTa-Marian-Training-1/checkpoint-12344
# Configuration saved in ./distilRoBERTa-Marian-Training-1/checkpoint-12344/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training-1/checkpoint-12344/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-12344/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-12344/special_tokens_map.json
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 40.24 and SacreBLEU of 39.05
# Saving model checkpoint to ./distilRoBERTa-Marian-Training-1/checkpoint-24688
# Configuration saved in ./distilRoBERTa-Marian-Training-1/checkpoint-24688/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training-1/checkpoint-24688/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-24688/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-24688/special_tokens_map.json
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 44.35 and SacreBLEU of 43.26
# Saving model checkpoint to ./distilRoBERTa-Marian-Training-1/checkpoint-37032
# Configuration saved in ./distilRoBERTa-Marian-Training-1/checkpoint-37032/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training-1/checkpoint-37032/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-37032/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-37032/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training-1/checkpoint-12344] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 46.65 and SacreBLEU of 45.66
# Saving model checkpoint to ./distilRoBERTa-Marian-Training-1/checkpoint-49376
# Configuration saved in ./distilRoBERTa-Marian-Training-1/checkpoint-49376/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training-1/checkpoint-49376/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-49376/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-49376/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training-1/checkpoint-24688] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 47.48 and SacreBLEU of 46.36
# Saving model checkpoint to ./distilRoBERTa-Marian-Training-1/checkpoint-61720
# Configuration saved in ./distilRoBERTa-Marian-Training-1/checkpoint-61720/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training-1/checkpoint-61720/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-61720/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-61720/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training-1/checkpoint-37032] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 51.23 and SacreBLEU of 50.22
# Saving model checkpoint to ./distilRoBERTa-Marian-Training-1/checkpoint-74064
# Configuration saved in ./distilRoBERTa-Marian-Training-1/checkpoint-74064/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training-1/checkpoint-74064/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-74064/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-74064/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training-1/checkpoint-49376] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 52.90 and SacreBLEU of 52.08
# Saving model checkpoint to ./distilRoBERTa-Marian-Training-1/checkpoint-86408
# Configuration saved in ./distilRoBERTa-Marian-Training-1/checkpoint-86408/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training-1/checkpoint-86408/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-86408/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-86408/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training-1/checkpoint-61720] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 54.25 and SacreBLEU of 53.41
# Saving model checkpoint to ./distilRoBERTa-Marian-Training-1/checkpoint-98752
# Configuration saved in ./distilRoBERTa-Marian-Training-1/checkpoint-98752/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training-1/checkpoint-98752/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-98752/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-98752/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training-1/checkpoint-74064] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 55.28 and SacreBLEU of 54.39
# Saving model checkpoint to ./distilRoBERTa-Marian-Training-1/checkpoint-111096
# Configuration saved in ./distilRoBERTa-Marian-Training-1/checkpoint-111096/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training-1/checkpoint-111096/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-111096/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-111096/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training-1/checkpoint-86408] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 56.71 and SacreBLEU of 55.84
# Saving model checkpoint to ./distilRoBERTa-Marian-Training-1/checkpoint-123440
# Configuration saved in ./distilRoBERTa-Marian-Training-1/checkpoint-123440/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training-1/checkpoint-123440/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-123440/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-123440/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training-1/checkpoint-98752] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 58.03 and SacreBLEU of 57.20
# Saving model checkpoint to ./distilRoBERTa-Marian-Training-1/checkpoint-135784
# Configuration saved in ./distilRoBERTa-Marian-Training-1/checkpoint-135784/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training-1/checkpoint-135784/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-135784/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-135784/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training-1/checkpoint-111096] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 57.86 and SacreBLEU of 57.17
# Saving model checkpoint to ./distilRoBERTa-Marian-Training-1/checkpoint-148128
# Configuration saved in ./distilRoBERTa-Marian-Training-1/checkpoint-148128/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training-1/checkpoint-148128/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-148128/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-148128/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training-1/checkpoint-123440] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 59.14 and SacreBLEU of 58.25
# Saving model checkpoint to ./distilRoBERTa-Marian-Training-1/checkpoint-160472
# Configuration saved in ./distilRoBERTa-Marian-Training-1/checkpoint-160472/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training-1/checkpoint-160472/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-160472/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-160472/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training-1/checkpoint-135784] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 58.77 and SacreBLEU of 57.96
# Saving model checkpoint to ./distilRoBERTa-Marian-Training-1/checkpoint-172816
# Configuration saved in ./distilRoBERTa-Marian-Training-1/checkpoint-172816/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training-1/checkpoint-172816/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-172816/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-172816/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training-1/checkpoint-148128] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2279: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# /usr/local/lib/python3.7/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:530: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# ***** Running Evaluation *****
#   Num examples = 1237
#   Batch size = 1
# INFO:seq_to_seq:Got BLEU of 58.70 and SacreBLEU of 57.92
# Saving model checkpoint to ./distilRoBERTa-Marian-Training-1/checkpoint-185160
# Configuration saved in ./distilRoBERTa-Marian-Training-1/checkpoint-185160/config.json
# Model weights saved in ./distilRoBERTa-Marian-Training-1/checkpoint-185160/pytorch_model.bin
# tokenizer config file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-185160/tokenizer_config.json
# Special tokens file saved in ./distilRoBERTa-Marian-Training-1/checkpoint-185160/special_tokens_map.json
# Deleting older checkpoint [distilRoBERTa-Marian-Training-1/checkpoint-160472] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./distilRoBERTa-Marian-Training-1/checkpoint-185160 (score: 0.4813149571418762).
# TrainOutput(global_step=185160, training_loss=0.2904757134933455, metrics={'train_runtime': 16896.1398, 'train_samples_per_second': 21.917, 'train_steps_per_second': 10.959, 'total_flos': 4887121626316800.0, 'train_loss': 0.2904757134933455, 'epoch': 15.0})

# %%
trainer.save_model()
trainer.save_state()

# %% [markdown]
# # **Visualize**

# %%
# %load_ext tensorboard

# %% [markdown]
# ### **distilRoBERTa-marian**

# %%
tensorboard --logdir ./distilroberta-Marian-Training/runs

# %% [markdown]
# # **Inference**

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
new_model = AutoModelForSeq2SeqLM.from_pretrained("./distilroberta-marian-training1/")
new_model.to("cuda")

new_tokenizer = AutoTokenizer.from_pretrained("./distilroberta-marian-training1/", use_fast=True)

# %%
new_model
# Out:
# EncoderDecoderModel(
#   (encoder): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): RobertaPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (decoder): MarianForCausalLM(
#     (model): MarianDecoderWrapper(
#       (decoder): MarianDecoder(
#         (embed_tokens): Embedding(67028, 512, padding_idx=67027)
#         (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#         (layers): ModuleList(
#           (0): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (3): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (4): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (5): MarianDecoderLayer(
#             (self_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (activation_fn): SiLUActivation()
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MarianAttention(
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (lm_head): Linear(in_features=512, out_features=67028, bias=False)
#   )
#   (enc_to_dec_proj): Linear(in_features=768, out_features=512, bias=True)
# )

# %%
new_model.config.max_length
# Out:
# 512

# %% [markdown]
# # **Evaluator**

# %%
# %cd Utils
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/CoNaLa/distilRoBERTa-Marian/Utils

# %%
from google.colab import files
import evaluator
evaluator = evaluator.CodeGenerationEvaluator(new_tokenizer, device,smooth_bleu=True)

# %%
batch_size = 1

# map data correctly
def generate_new_code(batch):
    inputs = new_tokenizer(batch["intent"], padding="max_length", truncation=True, max_length=512, return_tensors="pt")

    input_ids = inputs.input_ids.to("cuda")
    attention_mask = inputs.attention_mask.to("cuda")

    outputs = new_model.generate(input_ids, attention_mask=attention_mask)

    # all special tokens including will be removed
    output_str = new_tokenizer.batch_decode(outputs, skip_special_tokens=True)

    batch["pred_code"] = output_str

    return batch

# %%
results = test_dataset.map(generate_new_code, batched=True, batch_size=batch_size)

#results = test_dataset.map(generate_new_code, batched=True, batch_size=batch_size, remove_columns=["intent"])
# Out:
#   0%|          | 0/500 [00:00<?, ?ba/s]
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1268: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 512 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/models/CodeGeneration/New/CoNaLa/distilRoBERTa-Marian

# %%
import re
import string

import datasets
import numpy as np

import evaluate
from evaluate import load

# %%
exact_match = evaluate.load("exact_match")

#refs = ["The cat sat on the mat.", "Theaters are great.", "It's like comparing oranges and apples."]
#preds = ["The cat sat on the mat?", "Theaters are great.", "It's like comparing apples and oranges."]

"""
for i in range(len(results)):
  refs = results["code"][i]
  preds = results["pred_code"][i]
"""
# Out:
# Downloading builder script:   0%|          | 0.00/5.67k [00:00<?, ?B/s]
# '\nfor i in range(len(results)):\n  refs = results["code"][i]\n  preds = results["pred_code"][i]\n'

# %%
refs = results["snippet"]
preds = results["pred_code"]

# %%
exact_match_results = exact_match.compute(references=refs, predictions=preds, regexes_to_ignore=["▁", " "], ignore_case=True, ignore_punctuation=True, ignore_numbers=True)
print(round(exact_match_results["exact_match"], 5)*100)
# Out:
# 13.8

# %%
with open("./references.txt", 'w') as f:
  for i in range(len(results)):
    nl = results["intent"][i]
    ref = results["snippet"][i]
    pred = results["pred_code"][i]

    if pred is not None and pred != "":
      if ref is not None and ref != "":
        f.write(ref + '\n')
    else:
      continue


with open("./predictions.txt", 'w') as f:
  for i in range(len(results)):
    nl = results["intent"][i]
    ref = results["snippet"][i]
    pred = results["pred_code"][i]

    if pred is not None and pred != "":
      if ref is not None and ref != "":
        f.write(pred + '\n')
    else:
      continue

# %%
# Ok Evaluator
bleu_score =0
rouge_score = 0
sacre_bleu = 0

for i in range(len(results)):
  ref = results["snippet"][i]
  pred = results["pred_code"][i]
  if pred is not None and pred != "":
      if ref is not None and ref != "":
        #bleu_metric = metric.compute(predictions=[pred], references=[[ref]])
        #bleu_score  += bleu_metric["score"]

        bleu_metric = evaluator.evaluate([pred], [ref])
        #bleu_metric = evaluator.evaluateSingle(pred, ref)

        #bleu_score += bleu_metric['BLEU-Unigram-Precision']
        bleu_score += bleu_metric['BLEU']
        rouge_score += bleu_metric['ROUGE-L']
        sacre_bleu += bleu_metric['SacreBLEU']
        #print(bleu_metric['SacreBLEU'])
  else:
    continue

# %% [markdown]
# # **Performance Metrics**

# %% [markdown]
# **BLEU Score**

# %%
# distilRoBERTa-Marian
# print("Bleu Score: ",bleu_score/len(results))
print('Bleu Score: {} (scale 0-100)'.format(bleu_score/len(results)))
# Out:
# Bleu Score: 35.736454995041484 (scale 0-100)

# %% [markdown]
# **SacreBLEU**

# %%
print('Sacre Bleu: {} (scale 0-100)'.format(sacre_bleu/len(results)))
# Out:
# Sacre Bleu: 31.30251113133285 (scale 0-100)

# %% [markdown]
# **Rouge Score**

# %%
#distilRoBERTa-Marian
# print("Bleu Score: ",bleu_score/len(results))
print('ROUGE Score: {} (scale 0-100)'.format(rouge_score/len(results)))
# Out:
# ROUGE Score: 44.25465925857973 (scale 0-100)

# %% [markdown]
# **CodeBLEU**

# %%
from google.colab import files

# %%
import calc_code_bleu
ngram_match_score, weighted_ngram_match_score, syntax_match_score, dataflow_match_score, code_bleu_score = calc_code_bleu.calc_code_bleu("references.txt","predictions.txt","python", "keywords")

# %%
print("ngram_match_score: ", ngram_match_score*100)
print("weighted_ngram_match_score: ", weighted_ngram_match_score*100)
print("syntax_match_score: ", syntax_match_score*100)
print("dataflow_match_score: ", dataflow_match_score*100)
print("code_bleu_score: ", code_bleu_score*100)

# %% [markdown]
# # **Save the  results**

# %%
## %cd ..
# Out:
# /content/drive/MyDrive/models/CodeGeneration/MarianCG-CoNaLa-Large

# %%
pwd
# Out:
# '/content/drive/MyDrive/models/CodeGeneration/New/CoNaLa/distilRoBERTa-Marian'

# %%
bleu_score = 0
with open("./Output.txt", 'w') as f:
  for i in range(len(results)):
    nl = results["intent"][i]
    ref = results["snippet"][i]
    pred = results["pred_code"][i]

    if pred is not None and pred != "":
      if ref is not None and ref != "":

        bleu_metric = evaluator.evaluate([pred], [ref])
        f.write( "NL: " + nl + '\n')
        f.write( "ref: " + ref + '\n')
        f.write( "Output: " + pred + '\n')
        f.write("bleu_metric: " + str(bleu_metric["BLEU"]) + '\n')
        f.write(10*"-" + '\n')
        bleu_score  += bleu_metric["BLEU"]

    else:
      continue

# %% [markdown]
# # **Test**

# %%
# map data correctly
def generate_code(NL):
    inputs = new_tokenizer([NL], padding="max_length", truncation=True, max_length=512, return_tensors="pt")

    input_ids = inputs.input_ids.to("cuda")
    attention_mask = inputs.attention_mask.to("cuda")

    outputs = new_model.generate(input_ids, attention_mask=attention_mask)

    # all special tokens including will be removed
    output_code = new_tokenizer.batch_decode(outputs, skip_special_tokens=True)

    return output_code

# %%
#NL = "decode a hex string to utf-8."
NL = "remove first and last lines of string `s`"
output_code = generate_code(NL)

# %%
output_code

# %%
natural_language = "How I can get rid of None values in dictionary?"
gen_code = generate_code(natural_language)

# %%
gen_code
